# %% [markdown]
# # Evaluation results — ngmix vs ShearNet, metacal vs anacal
#
# Reads the single FITS `research/shear_bias/run.py` writes, which
# `research/unit_test_variations/sub.sh` produces for every run. One file, four
# extensions:
#
# | HDU | contents |
# |---|---|
# | `TAB_P` / `TAB_M` | the +γ / −γ shear populations, one row per object |
# | `LEAKAGE` | unsheared population with `R^PSF` per object |
# | `SUMMARY` | one row per (estimator, correction): m, c, R11, R22 |
#
# **Every plot below is produced once per correction**, so ngmix and ShearNet are
# always compared like for like:
#
# - **metacal** — shear the *image*: deconvolve, apply ±step, reconvolve with a
#   dilated PSF, re-measure. ngmix reads its response off its own fits to those
#   five images; ShearNet measures the same five images. From the network's side
#   this is not a deconvolution — it sees a galaxy with a slightly wider PSF.
# - **anacal** — AnaCal's *analytic* response, differentiated symbolically
#   through the fit with quintuple numbers (Li 2026, arXiv:2506.16607). Exact,
#   not a finite difference — but defined only for an estimator AnaCal can
#   differentiate, which here is its own Gaussian model fit.
# - **sim** — shear the *scene*: re-render at γ ± step with the galaxies, PSFs
#   and noise realisation all held fixed. Works for any estimator, black box or
#   differentiable, so it is the one column every row has.
#
# The two estimate the same derivative by different routes, so **disagreement
# between them is a finding**, not a nuisance.

# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table

# ── the run to plot ──────────────────────────────────────────────────────────
RUN = "/home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet"
EVAL_FITS = f"{RUN}/benchmarking/evaluation.fits"
OUTDIR = f"{RUN}/benchmarking/figures"
os.makedirs(OUTDIR, exist_ok=True)

plt.rcParams.update({
    "figure.dpi": 130, "font.size": 10, "axes.labelsize": 11,
    "axes.titlesize": 11, "legend.fontsize": 9,
    "axes.spines.top": False, "axes.spines.right": False,
})

# ngmix is the reference the results are read against, so it leads everywhere.
COLOR = {"ngmix": "#3B4CC0", "anacal": "#B40426", "shearnet": "#2ca02c"}
PRETTY = {"ngmix": "ngmix", "anacal": "AnaCal fit", "shearnet": "ShearNet"}
ORDER = ["ngmix", "anacal", "shearnet"]
CORRECTIONS = ["metacal", "anacal", "sim"]

with fits.open(EVAL_FITS) as hdul:
    HEADER = dict(hdul[0].header)
    tab_p = Table(hdul["TAB_P"].data)
    tab_m = Table(hdul["TAB_M"].data)
    leak = Table(hdul["LEAKAGE"].data)
    summary = Table(hdul["SUMMARY"].data)

N = len(tab_p)
SHEAR = float(HEADER.get("SHEAR_TR", 0.01))
STEP = float(HEADER.get("RESPONSE", 0.01))

# Which estimators are actually in this file, in the reference-first order.
EST = [e for e in ORDER if f"e_{e}" in tab_p.colnames]
# Which (estimator, correction) pairs have a response column.
HAVE = {(e, c) for e in EST for c in CORRECTIONS if f"R_{e}_{c}" in tab_p.colnames}

print(f"{EVAL_FITS}")
print(f"N = {N:,}  seed = {HEADER.get('SEED')}  backend = {HEADER.get('BACKEND')}  "
      f"applied shear = {SHEAR:+.4f}  response step = {STEP}")
print(f"estimators: {EST}")
print(f"pairs measured: {sorted(HAVE)}")

# %% [markdown]
# ## 1. The summary table

# %%
head = f"{'estimator':<12}{'correction':<12}{'m':>24}{'c':>24}{'R11':>9}{'R22':>9}{'N':>10}"
print(head); print("-" * len(head))
for row in summary:
    print(f"{row['estimator']:<12}{row['correction']:<12}"
          + f"{row['m']:+.5f} +/- {row['m_err']:.5f}".rjust(24)
          + f"{row['c']:+.6f} +/- {row['c_err']:.6f}".rjust(24)
          + f"{row['R11']:>9.4f}{row['R22']:>9.4f}{row['n_used']:>10,}")

# The comparison the corrections exist to make: same estimator, two routes to
# the same derivative.
print()
for e in EST:
    rows = {r["correction"]: r for r in summary if r["estimator"] == e}
    if len(rows) < 2:
        continue
    # Compare every correction this estimator has against its `sim` column,
    # which is the one every row carries.
    if "sim" not in rows:
        continue
    for other in ("anacal", "metacal"):
        if other not in rows:
            continue
        dm = rows[other]["m"] - rows["sim"]["m"]
        sigma = float(np.hypot(rows[other]["m_err"], rows["sim"]["m_err"]))
        tail = f"  ({dm / sigma:+.1f} sigma)" if sigma > 0 else ""
        print(f"{PRETTY.get(e, e):<12} m({other}) - m(sim) = {dm:+.5f}{tail}")

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 0.55 * len(summary) + 2.6))
labels = [f"{PRETTY.get(r['estimator'], r['estimator'])}  ({r['correction']})" for r in summary]
y = np.arange(len(summary))[::-1]

for ax, key, xlabel, scale, band in (
    (axes[0], "m", r"multiplicative bias  $m \times 10^{3}$", 1e3, 2.0),
    (axes[1], "c", r"additive bias  $c \times 10^{6}$", 1e6, None),
):
    vals = np.asarray(summary[key], float) * scale
    errs = np.asarray(summary[f"{key}_err"], float) * scale
    if band is not None:
        ax.axvspan(-band, band, color="0.88", zorder=0,
                   label=rf"$|m| < {band:g}\times10^{{-3}}$")
    ax.axvline(0.0, color="k", lw=1.0, ls="--", alpha=0.7, zorder=1)
    for yi, row, v, e in zip(y, summary, vals, errs):
        colour = COLOR.get(row["estimator"], "0.4")
        # filled = metacal, open = anacal, so the pairing reads at a glance
        filled = row["correction"] == "metacal"
        ax.errorbar(v, yi, xerr=e, fmt="o", ms=6.5, color=colour, capsize=3, lw=1.6,
                    mfc=colour if filled else "white", mew=1.6, zorder=3)
    ax.set_yticks(y); ax.set_yticklabels(labels)
    ax.set_ylim(-0.7, len(summary) - 0.3)
    ax.set_xlabel(xlabel)
    span = float(np.max(np.abs(vals) + errs))
    ax.set_xlim(-1.35 * span, 1.35 * span)
    # the label already carries the scale; matplotlib's own offset notation on
    # top of it reads as a second factor
    ax.ticklabel_format(axis="x", style="plain", useOffset=False)
    if band is not None:
        ax.legend(loc="upper right", frameon=False)

axes[0].set_title("Multiplicative bias    (filled = metacal, open = anacal)")
axes[1].set_title("Additive bias")
fig.tight_layout()
fig.savefig(f"{OUTDIR}/bias_summary.png", bbox_inches="tight")
fig.savefig(f"{OUTDIR}/bias_summary.pdf", bbox_inches="tight")
print(f"saved -> {OUTDIR}/bias_summary.png")

# %% [markdown]
# ## 2. Response distributions, one panel per correction
#
# `R11` per object. metacal and anacal estimate the same derivative, so the two
# panels should agree in the mean; the *widths* need not match, because the two
# routes have different noise properties.

# %%
def jack_err(values, njac=30):
    """Jackknife error on the ensemble mean -- the <R> the m estimate divides by."""
    a = np.asarray(values, float)
    a = a[np.isfinite(a)]
    if a.size < max(njac, 2):
        return np.nan
    chunks = np.array_split(np.arange(a.size), njac)
    means = np.array([a[np.setdiff1d(np.arange(a.size), ch, assume_unique=True)].mean()
                      for ch in chunks])
    return np.sqrt((njac - 1) * np.mean((means - means.mean()) ** 2))


fig, axes = plt.subplots(1, len(CORRECTIONS), figsize=(6 * len(CORRECTIONS), 4.0),
                         squeeze=False)
for ax, correction in zip(axes[0], CORRECTIONS):
    for e in EST:
        if (e, correction) not in HAVE:
            continue
        r11 = np.asarray(tab_p[f"R_{e}_{correction}"], float)[:, 0, 0]
        good = np.isfinite(r11)
        mean, err = np.nanmean(r11), jack_err(r11)
        ax.hist(r11[good], bins=80, histtype="step", lw=1.8, color=COLOR[e],
                label=rf"{PRETTY[e]}: $\langle R_{{11}}\rangle$ = {mean:.4f} $\pm$ {err:.4f}")
        ax.axvline(mean, color=COLOR[e], ls="--", lw=1.4)
    ax.set_xlabel(r"$R_{11}$")
    ax.set_ylabel("count")
    ax.set_title(f"{correction}")
    ax.legend(frameon=False, loc="upper left")
fig.suptitle("Per-object shear response", y=1.02)
fig.tight_layout()
fig.savefig(f"{OUTDIR}/response_hist.png", bbox_inches="tight")
print(f"saved -> {OUTDIR}/response_hist.png")

# %% [markdown]
# ### Response versus S/N

# %%
def bin_by(x, y, n_bins=12, min_count=50):
    """Mean y in equal-count bins of x, with the error on the mean.

    The bin count adapts down so a small run still produces a curve rather than
    an empty axis -- at N=400 twelve bins would leave 33 objects each and every
    bin would be dropped.
    """
    ok = np.isfinite(x) & np.isfinite(y)
    x, y = np.asarray(x)[ok], np.asarray(y)[ok]
    if x.size < min_count * 2:
        return None
    n_bins = int(min(n_bins, max(2, x.size // min_count)))
    edges = np.unique(np.quantile(x, np.linspace(0, 1, n_bins + 1)))
    idx = np.digitize(x, edges[1:-1])
    cx, cy, ce = [], [], []
    for i in range(len(edges) - 1):
        m = idx == i
        if m.sum() < min_count:
            continue
        cx.append(np.median(x[m])); cy.append(np.mean(y[m]))
        ce.append(np.std(y[m]) / np.sqrt(m.sum()))
    return np.array(cx), np.array(cy), np.array(ce)


s2n = np.asarray(tab_p["s2n"], float)
fig, axes = plt.subplots(1, len(CORRECTIONS), figsize=(6 * len(CORRECTIONS), 4.0),
                         squeeze=False, sharey=True)
for ax, correction in zip(axes[0], CORRECTIONS):
    for e in EST:
        if (e, correction) not in HAVE:
            continue
        binned = bin_by(s2n, np.asarray(tab_p[f"R_{e}_{correction}"], float)[:, 0, 0])
        if binned is None:
            continue
        cx, cy, ce = binned
        ax.fill_between(cx, cy - ce, cy + ce, color=COLOR[e], alpha=0.18, lw=0)
        ax.errorbar(cx, cy, yerr=ce, fmt="o-", ms=4, lw=1.6, capsize=2.5,
                    color=COLOR[e], label=PRETTY[e])
    if ax.lines:
        ax.set_xscale("log")
        ax.legend(frameon=False)
    else:
        ax.text(0.5, 0.5, "too few objects to bin", transform=ax.transAxes, ha="center")
    ax.set_xlabel("matched-filter S/N")
    ax.set_title(correction)
axes[0][0].set_ylabel(r"$R_{11}$")
fig.suptitle("Shear response versus S/N", y=1.02)
fig.tight_layout()
fig.savefig(f"{OUTDIR}/response_vs_snr.png", bbox_inches="tight")
print(f"saved -> {OUTDIR}/response_vs_snr.png")

# %% [markdown]
# ## 3. Calibrated shear, per correction
#
# The calibrated estimate is `ĝ = ⟨(e⁺ − e⁻)/2⟩ / ⟨(R⁺ + R⁻)/2⟩` — a ratio of
# means, not a mean of ratios, so that noise in a per-object response cannot bias
# it. Plotted against the applied shear as a residual, which is what `m` is.

# %%
fig, ax = plt.subplots(figsize=(7.5, 4.2))
ax.axhline(0.0, color="k", lw=1.0, ls="--", alpha=0.7)
ax.axhspan(-2e-3, 2e-3, color="0.88", zorder=0, label=r"$|m| < 2\times10^{-3}$")

x = np.arange(len(EST))
width = 0.36
for j, correction in enumerate(CORRECTIONS):
    xs, ys, es, colours = [], [], [], []
    for i, e in enumerate(EST):
        row = [r for r in summary if r["estimator"] == e and r["correction"] == correction]
        if not row:
            continue
        xs.append(i + (j - 0.5) * width)
        ys.append(float(row[0]["m"])); es.append(float(row[0]["m_err"]))
        colours.append(COLOR[e])
    ax.errorbar(xs, ys, yerr=es, fmt="o" if correction == "metacal" else "s",
                ms=8, lw=0, elinewidth=1.6, capsize=4,
                mfc="none" if correction == "anacal" else None,
                color="0.25", zorder=3, label=correction)
    for xi, yi, colour in zip(xs, ys, colours):
        ax.scatter([xi], [yi], s=60, color=colour, zorder=4,
                   marker="o" if correction == "metacal" else "s",
                   facecolors=colour if correction == "metacal" else "white",
                   edgecolors=colour, linewidths=1.8)
ax.set_xticks(x); ax.set_xticklabels([PRETTY[e] for e in EST])
ax.set_ylabel(r"$m$")
ax.set_title(f"Multiplicative bias by estimator and correction  (N = {N:,})")
ax.legend(frameon=False)
fig.tight_layout()
fig.savefig(f"{OUTDIR}/m_by_correction.png", bbox_inches="tight")
print(f"saved -> {OUTDIR}/m_by_correction.png")

# %% [markdown]
# ## 4. PSF leakage
#
# `R^PSF = ∂ê/∂e^PSF`, measured by offsetting every object's PSF shear by ±step
# with the galaxies and noise pinned. **Zero is exactly correct** — a shear
# estimate must not track the PSF's own ellipticity.
#
# This is the anacal (scene) route for every estimator. metacal has no
# counterpart unless the bootstrapper is configured with the `*_psf` shear types,
# which it is not, so there is one panel here rather than two.

# %%
present = [e for e in EST if f"Rpsf_{e}_sim" in leak.colnames]
fig, axes = plt.subplots(1, 2, figsize=(12, 4.4))

ax = axes[0]
names = [r"$R^{\rm PSF}_{11}$", r"$R^{\rm PSF}_{12}$",
         r"$R^{\rm PSF}_{21}$", r"$R^{\rm PSF}_{22}$"]
y = np.arange(4)[::-1]
spread = np.linspace(0.22, -0.22, max(len(present), 1))
for e, off in zip(present, spread):
    R = np.asarray(leak[f"Rpsf_{e}_sim"], float)
    mean = np.nanmean(R, axis=0).ravel()
    err = np.array([jack_err(R[:, a, b]) for a in range(2) for b in range(2)])
    ax.errorbar(mean, y + off, xerr=err, fmt="o", ms=5, color=COLOR[e],
                capsize=3, lw=1.4, label=PRETTY[e])
    for k in (0, 3):
        if np.isfinite(err[k]) and err[k] > 0:
            ax.annotate(f"{abs(mean[k]) / err[k]:.0f}$\\sigma$", (mean[k], y[k] + off),
                        textcoords="offset points", xytext=(0, 8), ha="center",
                        fontsize=7.5, color=COLOR[e])
ax.axvline(0.0, color="k", lw=1.0, ls="--", alpha=0.7)
ax.set_yticks(y); ax.set_yticklabels(names); ax.set_ylim(-0.7, 3.7)
ax.set_xlabel(r"$R^{\rm PSF} = \partial\hat{e}/\partial e^{\rm PSF}$")
ax.set_title(f"PSF-shear response (zero is correct)\nN = {len(leak):,}")
handles, hlabels = ax.get_legend_handles_labels()

ax = axes[1]
y = np.arange(2)[::-1]
spread = np.linspace(0.2, -0.2, max(len(present), 1))
for e, off in zip(present, spread):
    values = np.asarray(leak[f"e_{e}"], float)
    mean = np.nanmean(values, axis=0) * 1e3
    err = np.array([jack_err(values[:, k]) for k in (0, 1)]) * 1e3
    ax.errorbar(mean, y + off, xerr=err, fmt="o", ms=5, color=COLOR[e],
                capsize=3, lw=1.4, label=PRETTY[e])
ax.axvline(0.0, color="k", lw=1.0, ls="--", alpha=0.7)
ax.set_yticks(y)
ax.set_yticklabels([r"$\langle e_1 \rangle$", r"$\langle e_2 \rangle$"])
ax.set_ylim(-0.6, 1.6)
ax.set_xlabel(r"mean ellipticity $\times 10^{3}$ (uncorrected)")
ax.set_title("Raw mean shape")

fig.legend(handles, hlabels, loc="upper center", bbox_to_anchor=(0.5, 1.06),
           ncol=len(present), frameon=False)
fig.tight_layout()
fig.savefig(f"{OUTDIR}/psf_leakage.png", bbox_inches="tight")
fig.savefig(f"{OUTDIR}/psf_leakage.pdf", bbox_inches="tight")
print(f"saved -> {OUTDIR}/psf_leakage.png")

# %% [markdown]
# ### `R^PSF` versus S/N, and ⟨e⟩ against the PSF ellipticity

# %%
s2n_lk = np.asarray(leak["s2n"], float)
fig, ax = plt.subplots(figsize=(7.5, 4.2))
ax.axhline(0.0, color="k", lw=1.0, ls="--", alpha=0.7)
for e in present:
    binned = bin_by(s2n_lk, np.asarray(leak[f"Rpsf_{e}_sim"], float)[:, 0, 0])
    if binned is None:
        continue
    cx, cy, ce = binned
    ax.fill_between(cx, cy - ce, cy + ce, color=COLOR[e], alpha=0.18, lw=0)
    ax.errorbar(cx, cy, yerr=ce, fmt="o-", ms=4, lw=1.6, capsize=2.5,
                color=COLOR[e], label=PRETTY[e])
if ax.lines:
    ax.set_xscale("log")
    ax.legend(frameon=False)
else:
    ax.text(0.5, 0.5, "too few objects to bin", transform=ax.transAxes, ha="center")
ax.set_xlabel("matched-filter S/N")
ax.set_ylabel(r"$R^{\rm PSF}_{11}$")
ax.set_title("PSF response versus S/N (zero is correct)")
fig.tight_layout()
fig.savefig(f"{OUTDIR}/psf_response_vs_snr.png", bbox_inches="tight")
print(f"saved -> {OUTDIR}/psf_response_vs_snr.png")

# %%
gpsf = np.asarray(leak["gpsf"], float)
fig, axes = plt.subplots(1, 2, figsize=(12, 4.4), sharey=True)
for ax, comp in zip(axes, (0, 1)):
    ax.axhline(0.0, color="k", lw=1.0, ls="--", alpha=0.7)
    for e in present:
        binned = bin_by(gpsf[:, comp], np.asarray(leak[f"e_{e}"], float)[:, comp])
        if binned is None:
            continue
        cx, cy, ce = binned
        ax.errorbar(cx, cy, yerr=ce, fmt="o-", ms=4, lw=1.5, capsize=2.5,
                    color=COLOR[e], label=PRETTY[e])
    ax.set_xlabel(rf"$e_{comp + 1}^{{\rm PSF}}$")
    ax.set_title(rf"$\langle e_{comp + 1} \rangle$ vs PSF $e_{comp + 1}$")
axes[0].set_ylabel(r"$\langle e \rangle$")
axes[0].legend(frameon=False)
fig.suptitle(r"PSF leakage panels — the slope IS $R^{\rm PSF}$", y=1.02)
fig.tight_layout()
fig.savefig(f"{OUTDIR}/leakage_panels.png", bbox_inches="tight")
print(f"saved -> {OUTDIR}/leakage_panels.png")

# %% [markdown]
# ## 5. Recovered shape and size, against truth
#
# The supervised half of the picture: how well each estimator recovers the shape
# it was given, before any calibration. ngmix has no truth for hlr/flux in its
# output, so ShearNet's size and flux are shown against the catalog directly.

# %%
g_th = np.asarray(tab_p["g_th"], float)
fig, axes = plt.subplots(1, 2, figsize=(12, 4.4), sharey=True)
for ax, comp in zip(axes, (0, 1)):
    ax.axhline(0.0, color="k", lw=1.0, ls="--", alpha=0.7)
    for e in EST:
        resid = np.asarray(tab_p[f"e_{e}"], float)[:, comp] - g_th[:, comp]
        binned = bin_by(g_th[:, comp], resid)
        if binned is None:
            continue
        cx, cy, ce = binned
        ax.errorbar(cx, cy, yerr=ce, fmt="o-", ms=4, lw=1.5, capsize=2.5,
                    color=COLOR[e], label=PRETTY[e])
    ax.set_xlabel(rf"true $g_{comp + 1}$")
    ax.set_title(rf"$\hat{{e}}_{comp + 1} - g_{comp + 1}^{{\rm true}}$ (uncalibrated)")
axes[0].set_ylabel("residual")
axes[0].legend(frameon=False)
fig.tight_layout()
fig.savefig(f"{OUTDIR}/shape_residuals.png", bbox_inches="tight")
print(f"saved -> {OUTDIR}/shape_residuals.png")

# %%
panels = [("hlr_shearnet", "hlr_th", "half-light radius (arcsec)"),
          ("flux_shearnet", "flux_th", "flux")]
have = [(a, b, lab) for a, b, lab in panels
        if a in tab_p.colnames and b in tab_p.colnames]
if not have:
    print("no ShearNet size/flux predictions in this file "
          "(model.output_keys has only g1, g2)")
else:
    fig, axes = plt.subplots(1, len(have), figsize=(6 * len(have), 4.2), squeeze=False)
    for ax, (pred_col, true_col, label) in zip(axes[0], have):
        pred = np.asarray(tab_p[pred_col], float)
        true = np.asarray(tab_p[true_col], float)
        ok = np.isfinite(pred) & np.isfinite(true)
        ax.hexbin(true[ok], pred[ok], gridsize=45, bins="log", cmap="Greens", mincnt=1)
        lo, hi = np.nanpercentile(true[ok], [0.5, 99.5])
        ax.plot([lo, hi], [lo, hi], "k--", lw=1.2)
        ax.set_xlim(lo, hi); ax.set_ylim(lo, hi)
        ax.set_xlabel(f"true {label}"); ax.set_ylabel(f"ShearNet {label}")
        ax.set_title(label)
    fig.tight_layout()
    fig.savefig(f"{OUTDIR}/size_flux_recovery.png", bbox_inches="tight")
    print(f"saved -> {OUTDIR}/size_flux_recovery.png")

# %% [markdown]
# ## 5b. The familiar panels, unchanged
#
# `shearnet.plotting.scatter.plot_residuals` and `plot_true_vs_predicted`, and
# `shearnet.utils.superbit_plotter.PSFLeakagePanelMaker` — the same functions the
# old notebook called, fed from the new columns. Kept as the originals rather than
# reimplemented, so these figures are directly comparable to every one you have
# made before.
#
# Both `plot_*` helpers want `(N, 4)` arrays ordered `(g1, g2, sigma, flux)`.
# `sigma` is `sqrt(T/2)`, which for the catalog's `T = 2·HLR²` is exactly HLR — so
# the truth column is HLR itself and ngmix's is `sqrt(T_ngmix/2)`. (The old
# notebook used `sqrt(2)·HLR` here, which contradicted its own comment.)

# %%
from shearnet.plotting.scatter import plot_residuals, plot_true_vs_predicted


def four_column(estimator):
    """(g1, g2, sigma, flux) for an estimator, or None if the file lacks it."""
    if f"e_{estimator}" not in tab_p.colnames:
        return None
    e = np.asarray(tab_p[f"e_{estimator}"], float)
    if estimator == "ngmix":
        if "T_ngmix" not in tab_p.colnames:
            return None
        sigma = np.sqrt(np.abs(np.asarray(tab_p["T_ngmix"], float)) / 2.0)
        flux = np.asarray(tab_p["flux_ngmix"], float)
    else:
        if f"hlr_{estimator}" not in tab_p.colnames:
            return None
        sigma = np.asarray(tab_p[f"hlr_{estimator}"], float)
        flux = np.asarray(tab_p[f"flux_{estimator}"], float)
    return np.column_stack([e[:, 0], e[:, 1], sigma, flux])


true_4 = None
if "hlr_th" in tab_p.colnames and "flux_th" in tab_p.colnames:
    g = np.asarray(tab_p["g_th"], float)
    true_4 = np.column_stack([g[:, 0], g[:, 1],
                              np.asarray(tab_p["hlr_th"], float),
                              np.asarray(tab_p["flux_th"], float)])
pred_sn_4 = four_column("shearnet")
pred_ng_4 = four_column("ngmix")

if true_4 is None or pred_sn_4 is None or pred_ng_4 is None:
    print("need truth + ngmix + ShearNet with hlr/flux for these panels; "
          f"have truth={true_4 is not None}, ngmix={pred_ng_4 is not None}, "
          f"shearnet={pred_sn_4 is not None}")
else:
    plot_residuals(true_labels=true_4, predicted_labels=pred_sn_4,
                   preds_ngmix=pred_ng_4,
                   path=os.path.join(OUTDIR, "residuals_shearnet"))
    plot_true_vs_predicted(true_labels=true_4, predicted_labels=pred_sn_4,
                           preds_mcal=pred_ng_4, mcal=True,
                           path=os.path.join(OUTDIR, "true_vs_pred_shearnet"))
    plot_true_vs_predicted(true_labels=true_4, predicted_labels=pred_ng_4,
                           preds_mcal=pred_ng_4, mcal=True,
                           path=os.path.join(OUTDIR, "true_vs_pred_ngmix"))
    print(f"saved -> {OUTDIR}/residuals_shearnet.png and true_vs_pred_*.png")

# %% [markdown]
# ### PSF-leakage panels, via the vendored SuperBIT plotter
#
# `PSFLeakagePanelMaker` with the same `NBIN` / `MIN_COUNT` / `njac` the old
# notebook used, so the slope, the binning and the error bars are computed exactly
# as before — one figure per estimator plus the side-by-side comparison.

# %%
import shearnet.utils.superbit_plotter as plotter

# Same settings the old notebook used, so the slope, binning and error bars are
# computed exactly as before.
NBIN, MIN_COUNT, CALIBRATE, NJAC = 10, 20, False, 30
gpsf_lk = np.asarray(leak["gpsf"], float)
x_list = [(gpsf_lk[:, 0], r"$e_1^{\rm PSF}$"), (gpsf_lk[:, 1], r"$e_2^{\rm PSF}$")]

panelers = {}
for e in present:
    values = np.asarray(leak[f"e_{e}"], float)
    panelers[e] = plotter.PSFLeakagePanelMaker(
        e1_gal=values[:, 0], e2_gal=values[:, 1],
        NBIN=NBIN, MIN_COUNT=MIN_COUNT, CALIBRATE=CALIBRATE, njac=NJAC,
        color_e1=COLOR[e], color_e2="#B40426",
    )

for e, paneler in panelers.items():
    fig, axes = plt.subplots(2, 1, figsize=(8.5, 8.5), sharey=True)
    for ax, (x, xlab) in zip(axes, x_list):
        paneler.make_panel(ax, x_psf=x, xlab=xlab, showe1e2_leg=(ax is axes[0]))
        ax.set_ylabel(r"$\langle e \rangle$", fontsize=14)
    plt.suptitle(f"PSF Leakage - {PRETTY[e]}", fontsize=14, y=1.01)
    plt.tight_layout()
    fig.savefig(os.path.join(OUTDIR, f"psf_leakage_{e}.png"), dpi=150, bbox_inches="tight")
    print(f"saved -> {OUTDIR}/psf_leakage_{e}.png")

if len(panelers) >= 2:
    names = list(panelers)
    fig, axes = plt.subplots(2, len(names), figsize=(8 * len(names), 9), sharey="row")
    for col, e in enumerate(names):
        col_axes = axes[:, col]
        for ax, (x, xlab) in zip(col_axes, x_list):
            panelers[e].make_panel(ax, x_psf=x, xlab=xlab, showe1e2_leg=(ax is col_axes[0]))
            ax.set_ylabel(r"$\langle e \rangle$", fontsize=13)
        col_axes[0].set_title(f"PSF Leakage - {PRETTY[e]}", fontsize=13)
    plt.suptitle("PSF Leakage Comparison", fontsize=15, y=1.01)
    plt.tight_layout()
    fig.savefig(os.path.join(OUTDIR, "psf_leakage_comparison.png"), dpi=150, bbox_inches="tight")
    print(f"saved -> {OUTDIR}/psf_leakage_comparison.png")

# %% [markdown]
# ## 6. Size and S/N diagnostics

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4.0))

T_gal = np.asarray(tab_p["T_ngmix"], float) if "T_ngmix" in tab_p.colnames else None
T_psf = np.asarray(tab_p["Tpsf"], float)

if T_gal is not None:
    axes[0].hist(T_gal[np.isfinite(T_gal)], bins=60, color=COLOR["ngmix"], alpha=0.75,
                 label=r"$T_{\rm gal}$ (ngmix)")
axes[0].hist(T_psf[np.isfinite(T_psf)], bins=60, color="#B40426", alpha=0.75,
             label=r"$T_{\rm PSF}$ (admom)")
axes[0].set_xlabel(r"$T$ (arcsec$^2$)"); axes[0].set_ylabel("count")
axes[0].set_title("Size distributions"); axes[0].legend(frameon=False)

if T_gal is not None:
    ratio = T_gal / np.where(T_psf > 0, T_psf, np.nan)
    axes[1].hist(ratio[np.isfinite(ratio)], bins=60, color="purple", alpha=0.8)
    axes[1].axvline(1.0, color="k", ls="--", lw=1.2)
    axes[1].set_xlabel(r"$T_{\rm gal} / T_{\rm PSF}$")
    axes[1].set_title(f"Size ratio (median {np.nanmedian(ratio):.2f})")
else:
    axes[1].set_visible(False)

s2n_all = np.asarray(tab_p["s2n"], float)
good = np.isfinite(s2n_all) & (s2n_all > 0)
axes[2].hist(np.log10(s2n_all[good]), bins=60, color="coral", alpha=0.85)
axes[2].axvline(np.log10(np.median(s2n_all[good])), color="k", ls="--", lw=1.4,
                label=f"median S/N = {np.median(s2n_all[good]):.1f}")
axes[2].set_xlabel(r"$\log_{10}$ S/N"); axes[2].set_title("Signal-to-noise")
axes[2].legend(frameon=False)

fig.suptitle("Galaxy / PSF diagnostics", y=1.02)
fig.tight_layout()
fig.savefig(f"{OUTDIR}/size_snr_diagnostics.png", bbox_inches="tight")
print(f"saved -> {OUTDIR}/size_snr_diagnostics.png")

# %% [markdown]
# ## Reading these
#
# - **`m` divides by a response, and which response is the whole question.** The
#   metacal and anacal rows for one estimator are the same measurement calibrated
#   two ways. They should agree; where they do not, one of the two routes is
#   wrong for that estimator and the disagreement localises which.
# - **`⟨e⟩` in §4 is uncorrected**, so `⟨e⟩ ≈ 0` with `R^PSF ≠ 0` is not a
#   contradiction: the PSF ellipticity averages over the field, and a per-object
#   response leaves no *net* additive bias. It bites when `e^PSF` is spatially
#   coherent, which is the real SuperBIT case.
# - **Errors are pair-matched jackknife** (`RESAMPLE` in the header). σ(m) ≈
#   0.16/√N, so resolving |m| < 1e-3 needs N ≳ 2.6e4 before the error bar can see
#   it at all.
# - **metacal's random guesses depend on the worker count**; `NGMIX_NP` in the
#   header records the value used.
# - **The `anacal` row is the yardstick.** It is the only estimator with an
#   exact `de/dgamma` (quintuple numbers through the fit), so the size of
#   `m(anacal) - m(sim)` on that row is what tells you how much to trust the
#   `sim` column on the rows that have nothing else — ngmix and ShearNet.
# - FPFS is no longer run. Its columns were a subset of the same AnaCal
#   catalogue, and the analytical response now reaches model fitting.
