# %% [markdown]
# # ShearNet / ngmix Analysis Notebook
#
# **One input file:** `EVAL_FITS` — the `evaluation.fits` written by
# `research/shear_bias/run.py`. The benchmark is a single pass now, so everything
# this notebook plots lives in one file:
#
# - `TAB_P` / `TAB_M` — the +γ / −γ populations, one row per object. Uncorrected
#   and metacal-corrected predictions, size, flux, `R^γ`, and `R^PSF` live here.
# - `LEAKAGE` — the unsheared population carrying the metacal `R^PSF` products.
# - `SUMMARY` — the completely uncorrected (`none`) and fully corrected
#   (`metacal`) m/c rows for ngmix and ShearNet.
# - `BINNED` — the same two corrections in flux quantiles; each corrected bin
#   divides by its own within-bin metacal response.
# - `LEAKSUM` — one row per estimator: mean shape, metacal `R^PSF`, and whether
#   that response was applied to the leakage shapes.
# - `PRIMARY` header — seed, sample count, applied shear, jackknife blocks, timing.
#
# The sole response protocol for ngmix and ShearNet is **metacal**: deconvolve the
# image, apply the finite perturbation, and reconvolve with a dilated PSF. The
# notebook reads the canonical `Rgamma_<est>_metacal`, `Rpsf_<est>_metacal`, and
# `Rbarpsf_<est>_metacal` columns. It never substitutes a renderer/direct response.

# %% [markdown]
# ## 0 · Imports

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table

# Use the class from the superbit-lensing installation in this conda environment.
# There is deliberately no fallback to ShearNet's vendored wrapper.
from superbit_lensing.plotter import PSFLeakagePanelMaker
from shearnet.utils.plot_helpers import (
    plot_residuals,
    plot_true_vs_predicted,
)

plt.rcParams.update({
    'figure.dpi': 120,
    'font.size': 12,
    'axes.labelsize': 13,
    'axes.titlesize': 13,
    'legend.fontsize': 11,
})

COLORS = {
    'ngmix':    ('#3B4CC0', '#B40426'),
    'shearnet': ('#2ca02c', '#ff7f0e'),
}

# %% [markdown]
# ## 1 · Configuration

# %%
import os

# ── input file ───────────────────────────────────────────────────────────────
EVAL_FITS = '/home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/evaluation.fits'

# ── output directory (derived from the file location) ────────────────────────
OUTDIR      = os.path.dirname(EVAL_FITS)
METACAL_DIR = OUTDIR
LEAKAGE_DIR = OUTDIR

print(f"Reading      ← {EVAL_FITS}")
print(f"Plots        → {OUTDIR}")

# ── quality cuts: REMOVED (set to None) ──────────────────────────────────────
# No S/N or size selection, so the plotted sample matches the uncut ensemble the
# benchmark's m/c uses. Only failed/NaN ngmix fits are removed by the validity
# guard below; paired_bias removes the same failures.
S2N_MIN    = None
T_TPSF_MIN = None

# ── PSF leakage panel settings ───────────────────────────────────────────────
NBIN      = 10
MIN_COUNT = 20
CALIBRATE = False
NJAC      = 30

# ── jackknife blocks for the m/c cell (match eval.evaluate.n_jackknife) ──────
NJAC_MC = 20

# False plots the evaluator's metacal-R^PSF-corrected prediction; True plots the
# metacal noshear prediction before R^PSF subtraction. Both are stored in FITS.
# PSFLeakagePanelMaker receives `correct_psf_leakage=False` below because the
# selected FITS column already fixes the correction state; this avoids applying
# the upstream paneler's binned correction a second time.
PLOT_RAW = False
# Out:
# Reading      ← /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/evaluation.fits
# Plots        → /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking

# %% [markdown]
# ## 2 · Load the evaluation FITS

# %%
from astropy.io import fits

with fits.open(EVAL_FITS) as _hdul:
    HDR  = dict(_hdul['PRIMARY'].header)
    HDUS = [h.name for h in _hdul]

tab_p   = Table.read(EVAL_FITS, hdu='TAB_P')
tab_m   = Table.read(EVAL_FITS, hdu='TAB_M')
summary = Table.read(EVAL_FITS, hdu='SUMMARY')
print(f'HDUs       : {HDUS}')
print(f'TAB_P rows : {len(tab_p)}')
print(f'TAB_M rows : {len(tab_m)}')
print(f'Columns    : {tab_p.colnames}')
print(f"seed={HDR.get('SEED')}  samples={HDR.get('SAMPLES')}  "
      f"shear_true={HDR.get('SHEAR_TR')}  component=g{int(HDR.get('COMPONEN', 0)) + 1}  "
      f"backend={str(HDR.get('BACKEND', '')).strip()}")

def _get(tab, col, fallback=None):
    """Return np array for col if it exists, else fallback (None → all-NaN)."""
    if col in tab.colnames:
        return np.asarray(tab[col])
    if fallback is not None:
        return fallback
    return np.full(len(tab), np.nan)

RESPONSE_SUFFIXES = [''] + [
    f'_r{int(float(d))}'
    for d in str(HDR.get('RING', '0')).split(',')[1:] if d.strip()
]

def _metacal_rgamma_column(tab, estimator):
    """Best metacal R^gamma stem, preferring the complete ring product."""
    candidates = (f'Rgamma_{estimator}_metacal', f'R_{estimator}_metacal')
    available = [c for c in candidates if c in tab.colnames]
    if not available:
        return None
    # Older files suffix only the compatibility R_<est>_metacal alias at
    # extra ring stations. Pick whichever stem preserves the most stations;
    # both candidates are the same dilate/metacal finite difference.
    return max(available, key=lambda c: sum(f'{c}{s}' in tab.colnames
                                             for s in RESPONSE_SUFFIXES))

def _metacal_rgamma(tab, estimator, i, j):
    col = _metacal_rgamma_column(tab, estimator)
    if col is None:
        return np.full(len(tab), np.nan)
    columns = [f'{col}{s}' for s in RESPONSE_SUFFIXES if f'{col}{s}' in tab.colnames]
    response = np.mean([np.asarray(tab[name], float) for name in columns], axis=0)
    return response[:, i, j]

# ── ngmix quantities ──────────────────────────────────────────────────────────
_NAN2 = np.full((len(tab_p), 2), np.nan)
g_ngmix = _get(tab_p, 'e_ngmix_uncorrected', _get(tab_p, 'e_ngmix', _NAN2))
g_th    = _get(tab_p, 'g_th', _NAN2)
s2n     = _get(tab_p, 's2n')
T_gal   = _get(tab_p, 'T_ngmix')
T_psf   = _get(tab_p, 'Tpsf')
gpsf    = _get(tab_p, 'gpsf', _NAN2)
flags   = _get(tab_p, 'flag_ngmix', np.zeros(len(tab_p)))
flux_ng = _get(tab_p, 'flux_ngmix')

# The only response plotted or applied for ngmix is dilate/metacal R^gamma.
r11 = _metacal_rgamma(tab_p, 'ngmix', 0, 0)
r22 = _metacal_rgamma(tab_p, 'ngmix', 1, 1)
HAS_MCAL = np.isfinite(r11).any()
HAS_R22  = np.isfinite(r22).any()
print(f'ngmix metacal response available: {HAS_MCAL}   R22 available: {HAS_R22}')

# ── ShearNet quantities ───────────────────────────────────────────────────────
g_sn_noshear = _get(
    tab_p, 'e_shearnet_uncorrected', _get(tab_p, 'e_shearnet', _NAN2)
)
g_sn_raw = g_sn_noshear
r11_sn = _metacal_rgamma(tab_p, 'shearnet', 0, 0)
r22_sn = _metacal_rgamma(tab_p, 'shearnet', 1, 1)
g_sn_sigma = _get(tab_p, 'hlr_shearnet')
g_sn_flux  = _get(tab_p, 'flux_shearnet')

HAS_SN_SIGMA = not np.all(np.isnan(g_sn_sigma))
HAS_SN_FLUX  = not np.all(np.isnan(g_sn_flux))
HAS_SN       = not np.all(np.isnan(g_sn_noshear))
HAS_SN_MCAL  = np.isfinite(r11_sn).any()
print(f'ShearNet predictions present: {HAS_SN}   metacal response: {HAS_SN_MCAL}')

gal_hlr_th  = _get(tab_p, 'hlr_th')
gal_flux_th = _get(tab_p, 'flux_th')

# ── validity mask (no quality cuts; drops only failed/NaN ngmix fits) ────────
sel = np.ones(len(tab_p), dtype=bool)
if 'e_ngmix' in tab_p.colnames or 'e_ngmix_uncorrected' in tab_p.colnames:
    sel &= (flags == 0) & np.isfinite(g_ngmix[:, 0])
if 'T_ngmix' in tab_p.colnames:
    sel &= np.isfinite(T_gal)
if S2N_MIN is not None:
    sel &= (s2n > S2N_MIN)
if T_TPSF_MIN is not None:
    sel &= (T_gal / np.where(T_psf > 0, T_psf, np.nan) > T_TPSF_MIN)

print(f'Objects passing validity mask (no quality cuts): {sel.sum()} / {len(sel)}')

# ── masked working arrays ─────────────────────────────────────────────────────
G_NG    = g_ngmix[sel]
G_TH    = g_th[sel]
S2N_    = s2n[sel]
TG_     = T_gal[sel]
TP_     = T_psf[sel]
GPSF_   = gpsf[sel]
R11_    = r11[sel]
R22_    = r22[sel]
G_SN    = g_sn_noshear[sel]
G_SN_R  = g_sn_raw[sel]
R11_SN_ = r11_sn[sel]
R22_SN_ = r22_sn[sel]
HLR_TH_  = gal_hlr_th[sel]
FLUX_TH_ = gal_flux_th[sel]
G_SN_SIGMA = g_sn_sigma[sel]
G_SN_FLUX  = g_sn_flux[sel]
FLUX_NG = flux_ng[sel]
# Out:
# HDUs       : ['PRIMARY', 'TAB_P', 'TAB_M', 'TAB_P2', 'TAB_M2', 'LEAKAGE', 'SUMMARY', 'BINNED', 'LEAKSUM']
# TAB_P rows : 200000
# TAB_M rows : 200000
# ...

# %% [markdown]
# ## 3 · Load the PSF leakage table

# %%
cat_lk = Table.read(EVAL_FITS, hdu='LEAKAGE')
print(f'PSF leakage rows: {len(cat_lk)}')
print(f'Columns: {cat_lk.colnames}')

e1_psf_lk = np.asarray(cat_lk['gpsf'][:, 0])
e2_psf_lk = np.asarray(cat_lk['gpsf'][:, 1])

# run.py applies the ensemble dilate/metacal R^PSF correction to BOTH ngmix and
# ShearNet. LEAKSUM records that state; explicit raw and corrected columns let
# this notebook select either prediction without recomputing or double-applying.
LEAK_CORRECTED = {}
if 'LEAKSUM' in HDUS:
    leaksum = Table.read(EVAL_FITS, hdu='LEAKSUM')
    for row in leaksum:
        LEAK_CORRECTED[str(row['estimator']).strip()] = bool(row['corrected'])
else:
    leaksum = None
    for name in ('ngmix', 'shearnet'):
        corrected = f'e_{name}_metacal_corrected'
        raw = f'e_{name}_metacal_raw'
        if corrected in cat_lk.colnames and raw in cat_lk.colnames:
            LEAK_CORRECTED[name] = not np.allclose(
                np.asarray(cat_lk[corrected], float),
                np.asarray(cat_lk[raw], float), equal_nan=True)
        elif f'e_{name}' in cat_lk.colnames:
            LEAK_CORRECTED[name] = False

LEAK_TAG = {
    k: ('metacal raw (uncorrected)' if PLOT_RAW else r'metacal $R^{\rm PSF}$-corrected')
    for k in LEAK_CORRECTED
}
for name, corrected in sorted(LEAK_CORRECTED.items()):
    print(f'  {name:<9}: {"metacal R^PSF-corrected available" if corrected else "uncorrected only"}')

def _leak(name):
    """Select the explicit metacal raw or R^PSF-corrected leakage prediction."""
    if PLOT_RAW:
        order = (
            f'e_{name}_metacal_raw_ring', f'e_{name}_metacal_raw',
            f'e_{name}_raw_ring', f'e_{name}_raw', f'e_{name}_original',
        )
    else:
        order = (
            f'e_{name}_metacal_corrected_ring', f'e_{name}_metacal_corrected',
            f'e_{name}_ring', f'e_{name}',
        )
    for col in order:
        if col in cat_lk.colnames:
            return np.asarray(cat_lk[col], float), col
    return np.full((len(cat_lk), 2), np.nan), None

g_ng_lk, _col_ng = _leak('ngmix')
e1_gal_lk = g_ng_lk[:, 0]
e2_gal_lk = g_ng_lk[:, 1]
print(f'ngmix    leakage column plotted: {_col_ng}')
if _col_ng and _col_ng.endswith('_ring'):
    print('  (ring-averaged: intrinsic ellipticity is cancelled)')

g_sn_lk, _col_sn = _leak('shearnet')
print(f'ShearNet leakage column plotted: {_col_sn}')
HAS_SN_LK = not np.all(np.isnan(g_sn_lk))
print(f'ShearNet predictions in leakage table: {HAS_SN_LK}')

if HAS_SN_LK:
    e1_sn_lk = g_sn_lk[:, 0]
    e2_sn_lk = g_sn_lk[:, 1]

x_list = [
    (e1_psf_lk, r'$e_1^{\rm PSF}$'),
    (e2_psf_lk, r'$e_2^{\rm PSF}$'),
]
# Out:
# PSF leakage rows: 200000
# ...

# %% [markdown]
# ## 3b · m and c on the eval set — uncorrected and fully metacal-corrected
#
# Pair-matched multiplicative and additive bias, rebuilt from the per-object
# `TAB_P` / `TAB_M` products and checked against `SUMMARY`.
#
# For the corrected row, the evaluator first applies the ensemble metacal PSF
# response and then divides by the metacal shear response:
#
# $$e_{\rm corr}=e_{\rm mcal,raw}-\bar R^{\rm PSF}e^{\rm PSF},\qquad
# \hat\gamma=\langle R^\gamma_{\rm mcal}\rangle^{-1}
# \left\langle\frac{e^+_{\rm corr}-e^-_{\rm corr}}{2}\right\rangle,$$
#
# $$m=\hat\gamma_k/\gamma_{{\rm true},k}-1.$$
#
# The `none` row uses the original-stamp `e_<est>_uncorrected` prediction and the
# identity response, so neither `R^PSF` nor `R^γ` is applied. The `metacal` row
# uses `e_<est>_metacal_corrected` and `Rgamma_<est>_metacal`. Those are the only
# two corrections shown for ngmix and ShearNet; there is no direct/renderer row.
#
# Ratio-of-means errors use the same delete-one-block jackknife as the evaluator.
# When `shape_noise_cancel` is enabled, each prediction and response is averaged
# over its ring stations before m/c is computed.

# %%
import re

from shearnet.methods.anacal import ShapeMeasurement, paired_bias

SHEAR_TRUE = float(HDR.get('SHEAR_TR', 0.01))
COMPONENT  = int(HDR.get('COMPONEN', 0))
C_CONV     = str(HDR.get('C_CONVEN', 'shearnet')).strip()
RESAMPLE   = str(HDR.get('RESAMPLE', 'jackknife')).strip()
NJAC_FILE  = int(HDR.get('N_JACKKN', NJAC_MC))

RING = [d.strip() for d in str(HDR.get('RING', '0')).split(',') if d.strip()]
SUFFIXES = [''] + [f'_r{int(float(d))}' for d in RING[1:]]

TARGET_ESTIMATORS = ('ngmix', 'shearnet')
estimators = [
    name for name in TARGET_ESTIMATORS
    if (f'e_{name}_uncorrected' in tab_p.colnames or f'e_{name}' in tab_p.colnames)
]
pairs = [(name, correction) for name in estimators for correction in ('none', 'metacal')]

def _shape_column(estimator, correction):
    """Exact prediction used by each response state."""
    if correction == 'none':
        choices = (f'e_{estimator}_uncorrected', f'e_{estimator}')
    else:
        choices = (f'e_{estimator}_metacal_corrected', f'e_{estimator}_metacal')
    for col in choices:
        if col in tab_p.colnames and col in tab_m.colnames:
            return col
    return None

def _ringed(tab, name):
    columns = [f'{name}{s}' for s in SUFFIXES if f'{name}{s}' in tab.colnames]
    if not columns:
        raise KeyError(f'no column or ring station found for {name}')
    return np.mean([np.asarray(tab[c], float) for c in columns], axis=0)

def _flags(tab, estimator):
    bad = np.zeros(len(tab), bool)
    for suffix in SUFFIXES:
        col = f'flag_{estimator}{suffix}'
        if col in tab.colnames:
            bad |= np.asarray(tab[col], float) != 0
    return bad

def _shape(tab, estimator, correction, column):
    e = _ringed(tab, column)[:, :2]
    if correction == 'none':
        R = np.broadcast_to(np.eye(2), (len(e), 2, 2))
    else:
        response_col = _metacal_rgamma_column(tab, estimator)
        if response_col is None:
            raise KeyError(f'no metacal R^gamma column for {estimator}')
        R = _ringed(tab, response_col)
    return ShapeMeasurement(e=e, dedg=R, flags=_flags(tab, estimator))

print(f"gamma_true = {SHEAR_TRUE:+.4f} on g{COMPONENT + 1}   "
      f"c convention = '{C_CONV}'   resample = '{RESAMPLE}'   njac = {NJAC_MC}   "
      f"ring = {'/'.join(RING)} deg ({len(SUFFIXES)} station"
      f"{'s' if len(SUFFIXES) != 1 else ''})\n")
print("none = completely uncorrected original prediction; metacal = "
      "R^PSF-subtracted prediction divided by metacal R^gamma\n")
print(f"{'estimator':<10} {'correction':<10} {'m':>13} {'+/-':>10} "
      f"{'c':>13} {'+/-':>10} {'R11':>8} {'R22':>8} {'N':>8}  shape column")
print('-' * 112)

MC, skipped = {}, []
for estimator, correction in pairs:
    column = _shape_column(estimator, correction)
    response_col = _metacal_rgamma_column(tab_p, estimator)
    if column is None or (correction == 'metacal' and response_col is None):
        skipped.append((estimator, correction))
        continue
    bias = paired_bias(
        _shape(tab_p, estimator, correction, column),
        _shape(tab_m, estimator, correction, column),
        SHEAR_TRUE,
        component=COMPONENT, njac=NJAC_MC,
        c_convention=C_CONV, resample=RESAMPLE,
    )
    MC[(estimator, correction)] = bias
    print(f"{estimator:<10} {correction:<10} {bias.m:>+13.5e} {bias.m_err:>10.2e} "
          f"{bias.c:>+13.5e} {bias.c_err:>10.2e} "
          f"{bias.response[0, 0]:>8.4f} {bias.response[1, 1]:>8.4f} "
          f"{bias.n_used:>8d}  {column}")

for estimator, correction in skipped:
    print(f"{estimator:<10} {correction:<10}  skipped: required prediction or "
          "metacal R^gamma column is absent")

print('\n--- SUMMARY HDU, as written by the benchmark ---')
print(f"{'estimator':<10} {'correction':<10} {'m':>13} {'+/-':>10} "
      f"{'c':>13} {'+/-':>10}   check")
print('-' * 84)
for row in summary:
    est, corr = str(row['estimator']).strip(), str(row['correction']).strip()
    component = int(row['component'] if 'component' in summary.colnames else 0)
    if est not in TARGET_ESTIMATORS or corr not in ('none', 'metacal') or component != 0:
        continue
    bias = MC.get((est, corr))
    if bias is None:
        check = 'not rebuilt'
    elif NJAC_MC != NJAC_FILE:
        check = f'njac {NJAC_MC} != {NJAC_FILE}, not comparable'
    else:
        dm = abs(bias.m - float(row['m']))
        check = 'match' if dm <= 1e-9 * max(abs(bias.m), 1e-6) else f'DIFFERS by {dm:.3e}'
    print(f"{est:<10} {corr:<10} {row['m']:>+13.5e} {row['m_err']:>10.2e} "
          f"{row['c']:>+13.5e} {row['c_err']:>10.2e}   {check}")

if 'component' in summary.colnames and set(np.asarray(summary['component'])) >= {0, 1}:
    print('\n--- m and c per sheared component (SUMMARY) ---')
    print(f"{'estimator':<10} {'correction':<10} {'m1':>13} {'+/-':>10} "
          f"{'m2':>13} {'+/-':>10} {'c1':>12} {'c2':>12}")
    print('-' * 92)
    for est in TARGET_ESTIMATORS:
        for corr in ('none', 'metacal'):
            by = {int(r['component']): r for r in summary
                  if str(r['estimator']).strip() == est
                  and str(r['correction']).strip() == corr}
            if not {0, 1} <= set(by):
                continue
            print(f"{est:<10} {corr:<10} {by[0]['m']:>+13.5e} {by[0]['m_err']:>10.2e} "
                  f"{by[1]['m']:>+13.5e} {by[1]['m_err']:>10.2e} "
                  f"{by[0]['c']:>+12.4e} {by[1]['c']:>+12.4e}")
else:
    print('\n(only one shear component measured; set eval.evaluate.component: both for m2/c2)')

if 'BINNED' in HDUS:
    binned = Table.read(EVAL_FITS, hdu='BINNED')
    print(f"\n--- BINNED HDU: m per {str(HDR.get('BIN_BY', 'flux')).strip()} quantile "
          f"(metacal rows divide by their within-bin R^gamma) ---")
    for est in TARGET_ESTIMATORS:
        for corr in ('none', 'metacal'):
            rows = [r for r in binned
                    if str(r['estimator']).strip() == est
                    and str(r['correction']).strip() == corr
                    and int(r['component'] if 'component' in binned.colnames else 0) == 0]
            if not rows:
                continue
            cells = '  '.join(f"{r['m']:+.2e}" if np.isfinite(r['m']) else '   n/a   '
                              for r in rows)
            print(f"  {est:<9} {corr:<8} {cells}")
else:
    binned = None
    print('\n(no BINNED HDU in this file)')
# Out:
# gamma_true = +0.0100 on g1   c convention = 'lin2026'   resample = 'jackknife'   njac = 20   ring = 0/45/90/135 deg (4 stations)
#
# none = completely uncorrected original prediction; metacal = R^PSF-subtracted prediction divided by metacal R^gamma
#
# estimator  correction             m        +/-             c        +/-      R11      R22        N  shape column
# ----------------------------------------------------------------------------------------------------------------
# ngmix      none        -3.31103e-01   1.80e-03  +2.52504e-03   7.44e-05   1.0000   1.0000   200000  e_ngmix_uncorrected
# ngmix      metacal     +1.72112e-01   1.28e-02  +1.70808e-02   1.34e-04   0.6393   0.6586   200000  e_ngmix_metacal_corrected
# shearnet   none        -8.45900e-02   2.91e-04  -1.67538e-04   7.26e-05   1.0000   1.0000   200000  e_shearnet_uncorrected
# shearnet   metacal     +1.14561e-01   1.25e-02  -1.21722e-02   1.40e-04   0.9074   0.9031   200000  e_shearnet_metacal_corrected
#
# ...

# %% [markdown]
# ## 4 · g₁, g₂ residuals  (+ σ proxy)
#
# `plot_residuals` and `plot_true_vs_predicted` from `shearnet.utils.plot_helpers` expect
# `(N, 4)` arrays shaped `[g1, g2, sigma, flux]`.
# We construct these from the FITS columns: ngmix's σ = √(T/2) and flux = `flux_ngmix`;
# ShearNet's σ and flux are its own `hlr_shearnet` / `flux_shearnet` predictions.
# Truth comes from `g_th`, `hlr_th` and `flux_th`, which the evaluation now stores
# per object, so these really are residuals against truth.

# %%
# ── build (N, 4) arrays expected by plot_helpers ────────────────────────────
sigma_ng     = np.sqrt(np.abs(TG_) / 2.0)

# true sigma: convert catalog HLR to T convention: T = 2*HLR^2
true_sigma = np.sqrt(2) * HLR_TH_   # sqrt(T/2) = sqrt(2*HLR^2/2) = HLR

true_4    = np.column_stack([G_TH, true_sigma, FLUX_TH_])
pred_ng_4 = np.column_stack([G_NG, sigma_ng, FLUX_NG])

# ── ShearNet residuals ────────────────────────────────────────────────────────
if HAS_SN:
    sn_sigma_col = G_SN_SIGMA if HAS_SN_SIGMA else sigma_ng
    sn_flux_col  = G_SN_FLUX  if HAS_SN_FLUX  else FLUX_NG
    pred_sn_4 = np.column_stack([G_SN, sn_sigma_col, sn_flux_col])

    print("\n=== ShearNet residuals (vs truth g1/g2, vs ngmix sigma/flux) ===")
    plot_residuals(
        true_labels=true_4,
        predicted_labels=pred_sn_4,
        preds_ngmix=pred_ng_4,
        path=os.path.join(METACAL_DIR, "residuals_shearnet"),
    )
    print(f"Saved → {os.path.join(METACAL_DIR, 'residuals_shearnet.png')}")
else:
    # ── ngmix residuals ──────────────────────────────────────────────────────────
    print("=== ngmix residuals ===")
    plot_residuals(
        true_labels=true_4,
        predicted_labels=pred_ng_4,
        preds_ngmix=pred_ng_4,
        path=os.path.join(METACAL_DIR, "residuals_ngmix.png"),
    )
    print(f"Saved → {os.path.join(METACAL_DIR, 'residuals_ngmix.png')}")
# Out:
# === ShearNet residuals (vs truth g1/g2, vs ngmix sigma/flux) ===
# Saved → /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/residuals_shearnet.png

# %% [markdown]
# ## 4b · True vs predicted  (`plot_true_vs_predicted`)

# %%
plot_true_vs_predicted(
    true_labels=true_4,
    predicted_labels=pred_ng_4,
    preds_mcal=pred_ng_4,
    mcal=True,
    path=os.path.join(METACAL_DIR, "true_vs_pred_ngmix"),
)

if HAS_SN:
    plot_true_vs_predicted(
        true_labels=true_4,
        predicted_labels=pred_sn_4,
        preds_mcal=pred_ng_4,
        mcal=True,
        path=os.path.join(METACAL_DIR, "true_vs_pred_shearnet"),
    )

# %% [markdown]
# ## 5 · Size (T / σ) distributions

# %%
T_ratio    = TG_ / np.where(TP_ > 0, TP_, np.nan)
T_sigma    = np.sqrt(np.abs(TG_) / 2.0)
Tpsf_sigma = np.sqrt(np.abs(TP_) / 2.0)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

axes[0].hist(TG_[np.isfinite(TG_)], bins=60, color=COLORS['ngmix'][0], alpha=0.75,
             label=r'$T_{\rm gal}$')
axes[0].hist(TP_[np.isfinite(TP_)], bins=60, color=COLORS['ngmix'][1], alpha=0.75,
             label=r'$T_{\rm PSF}$')
axes[0].set_xlabel(r'$T$ (arcsec$^2$)')
axes[0].set_ylabel('Count')
axes[0].set_title('Size distributions')
axes[0].legend()

axes[1].hist(T_ratio[np.isfinite(T_ratio)], bins=60, color='purple', alpha=0.8)
axes[1].axvline(1.0, color='k', ls='--', lw=1.2,
                label=r'$T_{\rm gal} = T_{\rm PSF}$')
axes[1].set_xlabel(r'$T_{\rm gal} / T_{\rm PSF}$')
axes[1].set_ylabel('Count')
axes[1].set_title('Size ratio')
axes[1].legend()

axes[2].hist(T_sigma[np.isfinite(T_sigma)], bins=60,
             color=COLORS['shearnet'][0], alpha=0.75,
             label=r'$\sigma_{\rm gal} = \sqrt{T/2}$')
axes[2].hist(Tpsf_sigma[np.isfinite(Tpsf_sigma)], bins=60,
             color=COLORS['shearnet'][1], alpha=0.75,
             label=r'$\sigma_{\rm PSF} = \sqrt{T_{\rm PSF}/2}$')
axes[2].set_xlabel(r'$\sigma$ (arcsec)')
axes[2].set_ylabel('Count')
axes[2].set_title(r'$\sigma$ distributions')
axes[2].legend()

plt.suptitle('Galaxy / PSF Size Diagnostics', fontsize=14)
plt.tight_layout()

print(f'Median T_gal / T_PSF = {np.nanmedian(T_ratio):.3f}')
print(f'Median sigma_gal     = {np.nanmedian(T_sigma):.4f} arcsec')
print(f'Median sigma_PSF     = {np.nanmedian(Tpsf_sigma):.4f} arcsec')
plt.savefig(os.path.join(METACAL_DIR, "size_distributions.png"), dpi=150, bbox_inches="tight")
print(f"Saved → {os.path.join(METACAL_DIR, 'size_distributions.png')}")
# Out:
# Median T_gal / T_PSF = 1.650
# Median sigma_gal     = 0.2694 arcsec
# Median sigma_PSF     = 0.2139 arcsec
# Saved → /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/size_distributions.png

# %% [markdown]
# ## 6 · Flux / S/N distributions

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

valid_sn = np.isfinite(S2N_) & (S2N_ > 0)
axes[0].hist(S2N_[valid_sn], bins=60, color='steelblue', alpha=0.8)
axes[0].axvline(np.nanmedian(S2N_), color='k', ls='--', lw=1.5,
                label=f'Median = {np.nanmedian(S2N_):.1f}')
axes[0].set_xlabel('S/N')
axes[0].set_ylabel('Count')
axes[0].set_title('Signal-to-Noise distribution')
axes[0].legend()

axes[1].hist(np.log10(S2N_[valid_sn]), bins=60, color='coral', alpha=0.8)
axes[1].set_xlabel(r'$\log_{10}(\mathrm{S/N})$')
axes[1].set_ylabel('Count')
axes[1].set_title(r'$\log_{10}$ S/N distribution')

plt.suptitle('Flux / Signal-to-Noise Diagnostics', fontsize=14)
plt.tight_layout()

print(f'Median S/N = {np.nanmedian(S2N_):.2f}')
print(f'Mean   S/N = {np.nanmean(S2N_):.2f}')
print(f'S/N range  = [{np.nanmin(S2N_):.2f}, {np.nanmax(S2N_):.2f}]')
plt.savefig(os.path.join(METACAL_DIR, "snr_distributions.png"), dpi=150, bbox_inches="tight")
print(f"Saved → {os.path.join(METACAL_DIR, 'snr_distributions.png')}")
# Out:
# Median S/N = 85.41
# Mean   S/N = 136.52
# S/N range  = [51.02, 10598.60]
# Saved → /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/snr_distributions.png

# %% [markdown]
# ## 7 · Metacal Rᵞ response histogram
#
# The canonical `Rgamma_<est>_metacal` response for ngmix and ShearNet. Each
# finite difference uses the same deconvolve → shear → dilated-reconvolve image
# protocol. The compatibility alias `R_<est>_metacal` is accepted for older FITS.

# %%
# Dilate/metacal R^gamma with a jackknife error bar on the ensemble mean.
def _jack_err(arr, njac=30):
    """Jackknife error on the ensemble mean of a per-object response array."""
    a = np.asarray(arr, float); a = a[np.isfinite(a)]
    n = a.size
    if n < max(njac, 2):
        return np.nan
    chunks = np.array_split(np.arange(n), njac)
    ms = np.empty(njac)
    for k, ch in enumerate(chunks):
        mask = np.ones(n, bool); mask[ch] = False
        ms[k] = a[mask].mean()
    return np.sqrt((njac - 1) * np.mean((ms - ms.mean()) ** 2))

panels = []
if HAS_MCAL:
    panels.append(('ngmix metacal $R^\\gamma$', R11_, R22_, COLORS['ngmix'], HAS_R22))
if HAS_SN and HAS_SN_MCAL:
    has_r22_sn = not np.all(np.isnan(R22_SN_))
    panels.append(('ShearNet metacal $R^\\gamma$', R11_SN_, R22_SN_,
                   COLORS['shearnet'], has_r22_sn))

if not panels:
    print('Skipping — no metacal R^gamma columns in this file.')
else:
    fig, axes = plt.subplots(1, len(panels), figsize=(5 * len(panels), 4))
    if len(panels) == 1:
        axes = [axes]

    for ax, (title, r11_arr, r22_arr, cols, has_r22) in zip(axes, panels):
        vr = np.isfinite(r11_arr)
        m11, e11 = np.nanmean(r11_arr), _jack_err(r11_arr)
        ax.hist(r11_arr[vr], bins=60, color=cols[0], alpha=0.7, label=r'$R_{11}$')
        ax.axvline(m11, color=cols[0], ls='--', lw=1.8,
                   label=rf'$\langle R_{{11}} \rangle = {m11:.3f} \pm {e11:.3f}$')
        ax.axvspan(m11 - e11, m11 + e11, color=cols[0], alpha=0.25)
        ax.errorbar([m11], [0.92], xerr=[e11], transform=ax.get_xaxis_transform(),
                    fmt='o', color=cols[0], capsize=4, ms=5, zorder=5)
        if has_r22:
            vr2 = np.isfinite(r22_arr)
            m22, e22 = np.nanmean(r22_arr), _jack_err(r22_arr)
            ax.hist(r22_arr[vr2], bins=60, color=cols[1], alpha=0.7, label=r'$R_{22}$')
            ax.axvline(m22, color=cols[1], ls='-.', lw=1.8,
                       label=rf'$\langle R_{{22}} \rangle = {m22:.3f} \pm {e22:.3f}$')
            ax.errorbar([m22], [0.84], xerr=[e22], transform=ax.get_xaxis_transform(),
                        fmt='s', color=cols[1], capsize=4, ms=5, zorder=5)
        ax.set_xlabel('Metacal response'); ax.set_ylabel('Count'); ax.set_title(title)
        ax.legend(fontsize=9)

    plt.suptitle(r'Shear response diagnostics — dilate/metacal $R^\gamma$', fontsize=14)
    plt.tight_layout()

    if HAS_MCAL:
        print(f'ngmix   : <R11_metacal> = {np.nanmean(R11_):.4f} +/- {_jack_err(R11_):.4f}')
    if HAS_SN and HAS_SN_MCAL:
        print(f'ShearNet: <R11_metacal> = {np.nanmean(R11_SN_):.4f} +/- {_jack_err(R11_SN_):.4f}')
    plt.savefig(os.path.join(METACAL_DIR, 'r_gamma_metacal.png'), dpi=150, bbox_inches='tight')
    print(f"Saved -> {os.path.join(METACAL_DIR, 'r_gamma_metacal.png')}")
# Out:
# ngmix   : <R11_metacal> = 0.6364 +/- 0.0040
# ShearNet: <R11_metacal> = 0.8982 +/- 0.0010
# Saved -> /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/r_gamma_metacal.png

# %% [markdown]
# ## 7b · Metacal Rᵞ vs S/N — ngmix & ShearNet
#
# Quantile-binned median `Rgamma_<est>_metacal` as a function of S/N. Shaded band
# is ±1 SE and the dashed line is the bin median.

# %%
# ── bin the metacal response the same way process_catalog does ───────────────
def _bin_response(r_arr, snr_arr, n_bins=25):
    valid = np.isfinite(r_arr) & np.isfinite(snr_arr) & (snr_arr > 0)
    r, s = r_arr[valid], snr_arr[valid]
    edges = np.percentile(s, np.linspace(0, 100, n_bins + 1))
    idx = np.digitize(s, edges)
    centers, meds, errs = [], [], []
    for i in range(1, len(edges)):
        mask = idx == i
        if mask.sum() > 0:
            centers.append(np.median(s[mask]))
            meds.append(np.median(r[mask]))
            errs.append(np.std(r[mask]) / np.sqrt(mask.sum()))
    return np.array(centers), np.array(meds), np.array(errs)

def _as_sorted(x, y, e):
    x, y, e = np.asarray(x), np.asarray(y), np.asarray(e)
    m = np.isfinite(x) & np.isfinite(y) & np.isfinite(e)
    x, y, e = x[m], y[m], e[m]
    s = np.argsort(x)
    return x[s], y[s], e[s]

def style_log_x(ax, xlo, xhi):
    import matplotlib.ticker as mticker

    ax.set_xscale("log")
    ax.set_xlim(xlo, xhi)

    decades = np.arange(
        np.floor(np.log10(xlo)),
        np.ceil(np.log10(xhi)) + 1,
    )
    ticks = np.sort(np.concatenate([
        multiplier * 10.0**decades
        for multiplier in (1, 2, 5)
    ]))
    ticks = ticks[(ticks >= xlo) & (ticks <= xhi)]

    # Keep at most eight labeled ticks.
    if len(ticks) > 8:
        ticks = ticks[::int(np.ceil(len(ticks) / 8))]

    ax.xaxis.set_major_locator(mticker.FixedLocator(ticks))
    ax.xaxis.set_major_formatter(
        mticker.FuncFormatter(lambda x, _: f"{x:g}")
    )
    ax.xaxis.set_minor_locator(
        mticker.LogLocator(base=10, subs=np.arange(2, 10) * 0.1)
    )
    ax.xaxis.set_minor_formatter(mticker.NullFormatter())

    ax.tick_params(
        axis="x",
        which="major",
        labelsize=10,
        labelrotation=0,
        pad=6,
    )
    ax.tick_params(which="both", direction="out", top=False, right=False)

estimators = []
if HAS_MCAL:
    estimators.append({
        'label': 'ngmix',
        'components': [('r11', R11_, COLORS['ngmix'][0])]
                      + ([('r22', R22_, COLORS['ngmix'][1])] if HAS_R22 else []),
    })
if HAS_SN and HAS_SN_MCAL:
    has_r22_sn = not np.all(np.isnan(R22_SN_))
    estimators.append({
        'label': 'ShearNet',
        'components': [('r11', R11_SN_, COLORS['shearnet'][0])]
                      + ([('r22', R22_SN_, COLORS['shearnet'][1])] if has_r22_sn else []),
    })

if not estimators:
    print('Skipping — no metacal R^gamma columns in this file.')
else:
    fig, ax = plt.subplots(1, 1, figsize=(6, 3.75), constrained_layout=True)
    ymin, ymax = np.inf, -np.inf
    for est in estimators:
        for comp_label, r_arr, col in est['components']:
            x, y, e = _as_sorted(*_bin_response(r_arr, S2N_))
            ax.fill_between(x, y - e, y + e, color=col, alpha=0.18, linewidth=0)
            ax.plot(x, y, c=col, ls='--', lw=2.2, alpha=0.95)
            ax.errorbar(
                x, y, yerr=e, c=col, fmt='o', ms=4.0, mfc='white', mew=1.1,
                capsize=2.5, elinewidth=1.0, lw=0, alpha=0.95,
                label=fr"{est['label']} $R^{{\gamma}}_{{{'11' if comp_label == 'r11' else '22'}}}$",
            )
            ymin = min(ymin, np.nanmin(y - e))
            ymax = max(ymax, np.nanmax(y + e))

    ypad = 0.06 * (ymax - ymin) if np.isfinite(ymax - ymin) else 0.05
    ax.set_ylim(ymin - ypad, ymax + ypad)
    all_x = np.concatenate([
        _bin_response(r_arr, S2N_)[0]
        for est in estimators for _, r_arr, _ in est['components']
    ])
    all_x = all_x[np.isfinite(all_x) & (all_x > 0)]
    log_pad = 0.15 * (np.log10(all_x.max()) - np.log10(all_x.min()))
    xlo = 10 ** (np.log10(all_x.min()) - log_pad)
    xhi = 10 ** (np.log10(all_x.max()) + log_pad)
    ax.set_xlim(xlo, xhi)
    style_log_x(ax, xlo, xhi)
    ax.set_xlabel('S/N')
    ax.set_ylabel(r'Metacal $R^{\gamma}$')
    ax.set_title(r'Dilate/metacal $R^\gamma$ vs S/N', fontsize=12)
    ax.legend(frameon=False, fontsize=10, loc='upper left', bbox_to_anchor=(0.98, 0.98))

    plt.savefig(os.path.join(METACAL_DIR, 'r_gamma_vs_snr_metacal.png'),
                dpi=150, bbox_inches='tight')
    print(f"Saved -> {os.path.join(METACAL_DIR, 'r_gamma_vs_snr_metacal.png')}")
# Out:
# Saved -> /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/r_gamma_vs_snr_metacal.png

# %% [markdown]
# ## 7c · Metacal Rᴾˢᶠ response histogram
#
# The diagonal PSF responses are read only from `Rpsf_<est>_metacal`; the ensemble
# values actually subtracted by the evaluator come from
# `Rbarpsf_<est>_metacal`. Both ngmix and ShearNet use the same metacal
# `*_psf` perturbations and dilated reconvolution protocol.

# %%
# ── dilate/metacal PSF-response diagnostic ──────────────────────────────────
def _metacal_rpsf(cat, estimator, i=0, j=0):
    col = f'Rpsf_{estimator}_metacal'
    if col not in cat.colnames:
        return np.full(len(cat), np.nan)
    return np.asarray(cat[col], float)[:, i, j]

def _metacal_rbarpsf(cat, estimator, fallback):
    col = f'Rbarpsf_{estimator}_metacal'
    if col in cat.colnames:
        return np.asarray(cat[col], float)[0]
    return np.asarray(fallback, float)

R11_PSF_    = _metacal_rpsf(cat_lk, 'ngmix', 0, 0)
R22_PSF_    = _metacal_rpsf(cat_lk, 'ngmix', 1, 1)
R11_PSF_SN_ = _metacal_rpsf(cat_lk, 'shearnet', 0, 0)
R22_PSF_SN_ = _metacal_rpsf(cat_lk, 'shearnet', 1, 1)

RBAR_PSF_MATRIX = _metacal_rbarpsf(
    cat_lk, 'ngmix', [[np.nanmean(R11_PSF_), np.nan], [np.nan, np.nanmean(R22_PSF_)]])
RBAR_PSF_SN_MATRIX = _metacal_rbarpsf(
    cat_lk, 'shearnet', [[np.nanmean(R11_PSF_SN_), np.nan], [np.nan, np.nanmean(R22_PSF_SN_)]])

HAS_NG_RPSF = np.isfinite(R11_PSF_).any()
HAS_SN_RPSF = np.isfinite(R11_PSF_SN_).any()
panels = []
if HAS_NG_RPSF:
    panels.append(('ngmix', R11_PSF_, R22_PSF_, RBAR_PSF_MATRIX, COLORS['ngmix']))
if HAS_SN_RPSF:
    panels.append(('ShearNet', R11_PSF_SN_, R22_PSF_SN_,
                   RBAR_PSF_SN_MATRIX, COLORS['shearnet']))

if not panels:
    print('Skipping — no metacal R^PSF columns in this file.')
else:
    fig, axes = plt.subplots(1, len(panels), figsize=(5 * len(panels), 4))
    if len(panels) == 1:
        axes = [axes]
    for ax, (title, r11_arr, r22_arr, rbar, cols) in zip(axes, panels):
        for arr, component, color, linestyle in (
            (r11_arr, '11', cols[0], '--'), (r22_arr, '22', cols[1], '-.'),
        ):
            valid = np.isfinite(arr)
            if not valid.any():
                continue
            mean = float(rbar[int(component[0]) - 1, int(component[1]) - 1])
            err = _jack_err(arr)
            ax.hist(arr[valid], bins=60, color=color, alpha=0.5,
                    label=rf'$R^{{\rm PSF}}_{{{component}}}$')
            ax.axvline(mean, color=color, ls=linestyle, lw=2.0,
                       label=rf'$\bar R^{{\rm PSF}}_{{{component}}}={mean:+.4f}\pm{err:.4f}$')
            ax.axvspan(mean - err, mean + err, color=color, alpha=0.20)
        ax.axvline(0.0, color='k', ls=':', lw=1.0, alpha=0.6)
        ax.set_xlabel(r'per-object metacal $R^{\rm PSF}$')
        ax.set_ylabel('Count')
        ax.set_title(f'{title} metacal PSF response')
        ax.legend(fontsize=8)
    plt.suptitle(r'Dilate/metacal $R^{\rm PSF}$ used by the evaluator', fontsize=13)
    plt.tight_layout()

    if HAS_NG_RPSF:
        print(f'ngmix metacal Rbar^PSF:\n{RBAR_PSF_MATRIX}')
    if HAS_SN_RPSF:
        print(f'ShearNet metacal Rbar^PSF:\n{RBAR_PSF_SN_MATRIX}')
    plt.savefig(os.path.join(LEAKAGE_DIR, 'r_psf_metacal.png'), dpi=150, bbox_inches='tight')
    print(f"Saved -> {os.path.join(LEAKAGE_DIR, 'r_psf_metacal.png')}")
# Out:
# ngmix metacal Rbar^PSF:
# [[0.27357352 0.00280098]
#  [0.00204279 0.25106722]]
# ShearNet metacal Rbar^PSF:
# [[-0.38368695  0.00096464]
#  [ 0.00133087 -0.28349439]]
# Saved -> /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/r_psf_metacal.png

# %% [markdown]
# ## 7d · Metacal R₁₁ᴾˢᶠ vs S/N — ngmix & ShearNet
#
# Quantile-binned median `Rpsf_<est>_metacal[:, 0, 0]` as a function of S/N.
# Shaded band is ±1 SE and the dashed line is the bin median.

# %%
# ── bin the metacal PSF response the same way as R^gamma above ────────────────
S2N_LK = np.asarray(cat_lk['s2n']) if 's2n' in cat_lk.colnames else np.full(len(cat_lk), np.nan)

estimators = []
if HAS_NG_RPSF:
    estimators.append(('ngmix', R11_PSF_, COLORS['ngmix'][0]))
if HAS_SN_RPSF:
    estimators.append(('ShearNet', R11_PSF_SN_, COLORS['shearnet'][0]))

if not estimators:
    print('Skipping — no metacal R^PSF columns in this file.')
else:
    fig, ax = plt.subplots(1, 1, figsize=(6, 3.75), constrained_layout=True)
    ymin, ymax = np.inf, -np.inf
    for label, r_arr, color in estimators:
        x, y, e = _as_sorted(*_bin_response(r_arr, S2N_LK))
        ax.fill_between(x, y - e, y + e, color=color, alpha=0.18, linewidth=0)
        ax.plot(x, y, c=color, ls='--', lw=2.2, alpha=0.95)
        ax.errorbar(x, y, yerr=e, c=color, fmt='o', ms=4.0, mfc='white',
                    mew=1.1, capsize=2.5, elinewidth=1.0, lw=0, alpha=0.95,
                    label=fr'{label} metacal $R^{{\rm PSF}}_{{11}}$')
        ymin = min(ymin, np.nanmin(y - e))
        ymax = max(ymax, np.nanmax(y + e))

    ypad = 0.06 * (ymax - ymin) if np.isfinite(ymax - ymin) else 0.05
    ax.set_ylim(ymin - ypad, ymax + ypad)
    all_x = np.concatenate([_bin_response(r_arr, S2N_LK)[0]
                            for _, r_arr, _ in estimators])
    all_x = all_x[np.isfinite(all_x) & (all_x > 0)]
    log_pad = 0.15 * (np.log10(all_x.max()) - np.log10(all_x.min()))
    xlo = 10 ** (np.log10(all_x.min()) - log_pad)
    xhi = 10 ** (np.log10(all_x.max()) + log_pad)
    ax.set_xlim(xlo, xhi)
    style_log_x(ax, xlo, xhi)
    ax.set_xlabel('S/N')
    ax.set_ylabel(r'Metacal $R^{\rm PSF}_{11}$')
    ax.set_title(r'Dilate/metacal $R^{\rm PSF}_{11}$ vs S/N')
    ax.legend(frameon=False, fontsize=10, loc='upper left', bbox_to_anchor=(0.98, 0.98))

    plt.savefig(os.path.join(LEAKAGE_DIR, 'r_psf_vs_snr_metacal.png'),
                dpi=150, bbox_inches='tight')
    print(f"Saved -> {os.path.join(LEAKAGE_DIR, 'r_psf_vs_snr_metacal.png')}")
# Out:
# Saved -> /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/r_psf_vs_snr_metacal.png

# %% [markdown]
# ## 8 · PSF leakage — ngmix
#
# Uses `PSFLeakagePanelMaker` directly from `superbit_lensing.plotter`. The paneler
# is given the measured metacal `R^PSF` arrays required by the installed API.
# `correct_psf_leakage=False` prevents a second correction because `_leak` already
# selects either the evaluator's explicit raw or corrected FITS prediction.

# %%
paneler_ng = PSFLeakagePanelMaker(
    e1_gal=e1_gal_lk,
    e2_gal=e2_gal_lk,
    e1_psf=e1_psf_lk,
    e2_psf=e2_psf_lk,
    r11_psf=R11_PSF_,
    r22_psf=R22_PSF_,
    NBIN=NBIN,
    MIN_COUNT=MIN_COUNT,
    CALIBRATE=CALIBRATE,
    njac=NJAC,
    color_e1=COLORS['ngmix'][0],
    color_e2=COLORS['ngmix'][1],
    correct_psf_leakage=False,
)

fig, axes = plt.subplots(2, 1, figsize=(8.5, 8.5), sharey=True)
for ax, (x, xlab) in zip(axes, x_list):
    paneler_ng.make_panel(ax, x_psf=x, xlab=xlab,
                          showe1e2_leg=(ax is axes[0]))

axes[0].set_ylabel(r'$\langle e \rangle$', fontsize=14)
axes[1].set_ylabel(r'$\langle e \rangle$', fontsize=14)
plt.suptitle(f'PSF Leakage — ngmix ({LEAK_TAG.get("ngmix", "?")})',
             fontsize=14, y=1.01)
plt.tight_layout()

plt.savefig(os.path.join(LEAKAGE_DIR, 'psf_leakage_ngmix.png'), dpi=150, bbox_inches='tight')
print(f"Saved → {os.path.join(LEAKAGE_DIR, 'psf_leakage_ngmix.png')}")
# Out:
# Saved → /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/psf_leakage_ngmix.png

# %% [markdown]
# ## 9 · PSF leakage — ShearNet
# *(skipped if ShearNet predictions are absent from the leakage file)*

# %%
if not HAS_SN_LK:
    print('Skipping — no ShearNet predictions found in PSF leakage file.')
else:
    paneler_sn = PSFLeakagePanelMaker(
        e1_gal=e1_sn_lk,
        e2_gal=e2_sn_lk,
        e1_psf=e1_psf_lk,
        e2_psf=e2_psf_lk,
        r11_psf=R11_PSF_SN_,
        r22_psf=R22_PSF_SN_,
        NBIN=NBIN,
        MIN_COUNT=MIN_COUNT,
        CALIBRATE=CALIBRATE,
        njac=NJAC,
        color_e1=COLORS['shearnet'][0],
        color_e2=COLORS['shearnet'][1],
        correct_psf_leakage=False,
    )

    fig, axes = plt.subplots(2, 1, figsize=(8.5, 8.5), sharey=True)
    for ax, (x, xlab) in zip(axes, x_list):
        paneler_sn.make_panel(ax, x_psf=x, xlab=xlab,
                              showe1e2_leg=(ax is axes[0]))

    axes[0].set_ylabel(r'$\langle e \rangle$', fontsize=14)
    axes[1].set_ylabel(r'$\langle e \rangle$', fontsize=14)
    plt.suptitle(f'PSF Leakage — ShearNet ({LEAK_TAG.get("shearnet", "?")})',
                 fontsize=14, y=1.01)
    plt.tight_layout()

    plt.savefig(os.path.join(LEAKAGE_DIR, 'psf_leakage_shearnet.png'),
                dpi=150, bbox_inches='tight')
    print(f"Saved → {os.path.join(LEAKAGE_DIR, 'psf_leakage_shearnet.png')}")
# Out:
# Saved → /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/psf_leakage_shearnet.png

# %% [markdown]
# ## 10 · PSF leakage — side-by-side comparison
# *(only when ShearNet is present)*

# %%
if not HAS_SN_LK:
    print('Skipping comparison — no ShearNet predictions found.')
else:
    fig, axes = plt.subplots(2, 2, figsize=(16, 9), sharey='row')

    for paneler, title, tag, col_axes in [
        (paneler_ng, 'ngmix',    LEAK_TAG.get('ngmix', '?'),    axes[:, 0]),
        (paneler_sn, 'ShearNet', LEAK_TAG.get('shearnet', '?'), axes[:, 1]),
    ]:
        for ax, (x, xlab) in zip(col_axes, x_list):
            paneler.make_panel(ax, x_psf=x, xlab=xlab,
                               showe1e2_leg=(ax is col_axes[0]))
        col_axes[0].set_title(f'PSF Leakage — {title} ({tag})', fontsize=13)
        col_axes[0].set_ylabel(r'$\langle e \rangle$', fontsize=13)
        col_axes[1].set_ylabel(r'$\langle e \rangle$', fontsize=13)

    plt.suptitle('PSF Leakage Comparison: ngmix vs ShearNet', fontsize=15, y=1.01)
    plt.tight_layout()

    plt.savefig(os.path.join(LEAKAGE_DIR, "psf_leakage_comparison.png"), dpi=150, bbox_inches="tight")
    print(f"Saved → {os.path.join(LEAKAGE_DIR, 'psf_leakage_comparison.png')}")
# Out:
# Saved → /home/adfield/ShearNet/research/unit_test_variations/fourth_inloop_shearnet_d4_2drope/benchmarking/psf_leakage_comparison.png

# %% [markdown]
# ## Training-distribution asymmetry diagnostic
#
# Tests whether the **e1-clean / e2-broken** PSF leakage ($\alpha_{11}\!\approx\!0.005$ at $1\sigma$ vs $\alpha_{22}\!\approx\!0.040$ at $8\sigma$) is explained by **asymmetric coverage of $e_2^{\rm PSF}$ vs $e_1^{\rm PSF}$** in the data the network saw, rather than by architecture. If $e_2^{\rm PSF}$ is narrower, skewed, or sparse at the extremes, the network had less signal to learn $e_2$ deconvolution from — a cheap fix (resample symmetric + retrain) before anything architectural.

# %%
# # ── Training-distribution asymmetry diagnostic ──────────────────────────────
# from scipy.stats import ks_2samp, skew

# # reload leakage columns if this cell is run before/without §3
# try:
#     e1_psf_lk, e2_psf_lk, G_TH, HLR_TH_, FLUX_TH_
# except NameError:
#     cat_lk    = Table.read(PSF_LEAKAGE_FITS)
#     e1_psf_lk = np.asarray(cat_lk['gpsf'][:, 0])
#     e2_psf_lk = np.asarray(cat_lk['gpsf'][:, 1])

# def _clean(x):
#     x = np.asarray(x, float)
#     return x[np.isfinite(x)]

# def _summ(x, label):
#     x = _clean(x)
#     return dict(label=label, n=x.size, mean=x.mean(), std=x.std(), skew=skew(x),
#                 lo=np.percentile(x, 0.5), hi=np.percentile(x, 99.5), arr=x)

# def _compare(a, b, name):
#     ks    = ks_2samp(a['arr'], b['arr'])
#     ratio = b['std'] / a['std']
#     asym  = (ks.pvalue < 1e-3 or not 0.9 < ratio < 1.111
#              or abs(a['skew']) > 0.15 or abs(b['skew']) > 0.15)
#     flag  = '  <<< ASYMMETRIC' if asym else '  ok'
#     print(f"[{name}]")
#     for s in (a, b):
#         print(f"  {s['label']:8s} n={s['n']:>7d} mean={s['mean']:+.4f} "
#               f"std={s['std']:.4f} skew={s['skew']:+.3f} "
#               f"1-99.5%=[{s['lo']:+.3f},{s['hi']:+.3f}]")
#     print(f"  std ratio (2nd/1st) = {ratio:.3f}   "
#           f"KS D={ks.statistic:.3f} p={ks.pvalue:.2e}{flag}\n")

# e1p = _summ(e1_psf_lk, 'e1_psf'); e2p = _summ(e2_psf_lk, 'e2_psf')
# print("=== PSF ellipticity coverage (the leakage-relevant axis) ===")
# _compare(e1p, e2p, 'PSF ellipticity')

# g1s = _summ(G_TH[:, 0], 'g1'); g2s = _summ(G_TH[:, 1], 'g2')
# print("=== Applied shear coverage ===")
# _compare(g1s, g2s, 'applied shear')

# # ── plots ───────────────────────────────────────────────────────────────────
# fig, ax = plt.subplots(2, 3, figsize=(16, 9))

# # (0,0) PSF ellipticity marginals — the headline panel
# pr = (min(e1p['arr'].min(), e2p['arr'].min()), max(e1p['arr'].max(), e2p['arr'].max()))
# bp = np.linspace(*pr, 60)
# ax[0,0].hist(e1p['arr'], bins=bp, density=True, histtype='step', lw=2,
#              color=COLORS['ngmix'][0], label=r'$e_1^{\rm PSF}$')
# ax[0,0].hist(e2p['arr'], bins=bp, density=True, histtype='step', lw=2,
#              color=COLORS['ngmix'][1], label=r'$e_2^{\rm PSF}$')
# ax[0,0].axvline(e1p['mean'], color=COLORS['ngmix'][0], ls=':', lw=1)
# ax[0,0].axvline(e2p['mean'], color=COLORS['ngmix'][1], ls=':', lw=1)
# ax[0,0].set_xlabel('PSF ellipticity'); ax[0,0].set_ylabel('density')
# ax[0,0].set_title('PSF ellipticity marginals'); ax[0,0].legend()

# # (0,1) 2D coverage — holes = unlearned (e1,e2) regions
# hb = ax[0,1].hexbin(e1p['arr'], e2p['arr'], gridsize=40, bins='log',
#                     mincnt=1, cmap='viridis')
# ax[0,1].set_xlabel(r'$e_1^{\rm PSF}$'); ax[0,1].set_ylabel(r'$e_2^{\rm PSF}$')
# ax[0,1].set_title('PSF coverage (holes = unlearned)'); ax[0,1].set_aspect('equal')
# fig.colorbar(hb, ax=ax[0,1], label='log N')

# # (0,2) per-bin counts over the SAME binning the leakage panel uses (NBIN)
# lo = min(e1p['arr'].min(), e2p['arr'].min())
# hi = max(e1p['arr'].max(), e2p['arr'].max())
# edges = np.linspace(lo, hi, NBIN + 1); cen = 0.5 * (edges[:-1] + edges[1:])
# c1, _ = np.histogram(e1p['arr'], bins=edges)
# c2, _ = np.histogram(e2p['arr'], bins=edges)
# w = (edges[1] - edges[0]) * 0.4
# ax[0,2].bar(cen - w/2, c1, width=w, color=COLORS['ngmix'][0], label=r'$e_1^{\rm PSF}$')
# ax[0,2].bar(cen + w/2, c2, width=w, color=COLORS['ngmix'][1], label=r'$e_2^{\rm PSF}$')
# ax[0,2].axhline(MIN_COUNT, color='k', ls='--', lw=1, label=f'MIN_COUNT={MIN_COUNT}')
# ax[0,2].set_xlabel('PSF ellipticity bin'); ax[0,2].set_ylabel('objects / bin')
# ax[0,2].set_title(f'Per-bin counts (NBIN={NBIN})'); ax[0,2].legend()

# # (1,0) applied-shear marginals
# sr = (min(g1s['arr'].min(), g2s['arr'].min()), max(g1s['arr'].max(), g2s['arr'].max()))
# bs = np.linspace(*sr, 60)
# ax[1,0].hist(g1s['arr'], bins=bs, density=True, histtype='step', lw=2,
#              color=COLORS['shearnet'][0], label=r'$g_1$')
# ax[1,0].hist(g2s['arr'], bins=bs, density=True, histtype='step', lw=2,
#              color=COLORS['shearnet'][1], label=r'$g_2$')
# ax[1,0].set_xlabel('applied shear'); ax[1,0].set_ylabel('density')
# ax[1,0].set_title('Applied-shear marginals'); ax[1,0].legend()

# # (1,1) HLR coverage
# hlr = _clean(HLR_TH_)
# ax[1,1].hist(hlr, bins=60, color='purple', alpha=0.8)
# ax[1,1].set_xlabel('HLR (arcsec)'); ax[1,1].set_ylabel('count')
# ax[1,1].set_title(f'HLR  (median {np.median(hlr):.3f})')

# # (1,2) flux coverage
# flux = _clean(FLUX_TH_)
# ax[1,2].hist(flux, bins=60, color='teal', alpha=0.8)
# ax[1,2].set_xlabel('flux'); ax[1,2].set_ylabel('count')
# ax[1,2].set_title(f'flux  (median {np.median(flux):.1f})')
# if (flux > 0).all() and flux.max() / max(flux.min(), 1e-12) > 50:
#     ax[1,2].set_xscale('log')

# plt.suptitle('Training-distribution asymmetry diagnostic', fontsize=15, y=1.01)
# plt.tight_layout()
# plt.savefig(os.path.join(LEAKAGE_DIR, "training_distribution_asymmetry.png"),
#             dpi=150, bbox_inches="tight")
# print(f"Saved \u2192 {os.path.join(LEAKAGE_DIR, 'training_distribution_asymmetry.png')}")
# plt.show()

# %% [markdown]
# ## Train-vs-eval PSF distribution probe
#
# Train and eval use the **same PSFEx file** and sample PSF positions uniformly over the same 9600×6400 field — only the seed differs (`train.seed=42`, `eval.seed=150`). So they draw $e^{\rm PSF}$ from the *same distribution*; the seed picks a different realization, not a different distribution. This cell replays the exact per-object position draws of `make_data` for **both seeds** through the real `DES_PSFEx` model, measures $e^{\rm PSF}$ at each (HSM), and prints a **worse / equal / better** verdict per component. It also validates the replay against the real eval `gpsf` (em5) already loaded in §3.

# %%
# # ── Train-vs-eval PSF distribution probe (seed 42 vs 150, same PSFEx) ────────
# # main.py.make_data samples PSF positions UNIFORMLY over the 9600x6400 field and
# # evaluates the SAME PSFEx model; only the seed differs (train=42, eval=150).
# # This replays the exact per-object position draws for each seed, measures e_PSF
# # at each position (HSM adaptive moments), and asks: is the TRAINING e_PSF
# # distribution worse / equal / better than EVAL?  If equal, the e2 leakage is an
# # estimator property, not a train/eval distribution shift.
# import galsim, galsim.des
# import shearnet.utils.superbit as utils  # vendored from superbit-lensing
# from astropy.io import fits as _fits

# # --- mirror main.py / config constants ---
# PSFEX_FILE  = '/home/adfield/SHEARNET_DATA/psfex-output/Abell3411_1_300_1684688714_clean_starcat.psf'
# TRAIN_SEED, EVAL_SEED = 42, 150
# TRAIN_CAT   = '/home/adfield/ShearNet/cosmos_catalog_train.fits'
# EVAL_CAT    = '/home/adfield/ShearNet/cosmos_catalog_eval.fits'
# IMAGE_XSIZE, IMAGE_YSIZE, MARGIN = 9600, 6400, 500
# PSF_NPIX_   = PSF_NPIX if 'PSF_NPIX' in dir() else 53
# SCALE_      = SCALE    if 'SCALE'    in dir() else 0.141
# N_SAMPLE    = 20000     # positions replayed per seed; raise toward 300000/200000 for the full draw

# GP = galsim.des.DES_PSFEx(PSFEX_FILE, wcs=utils.get_galsim_tanwcs())

# def _catlen(path, default=100000):
#     try:
#         with _fits.open(path) as h:
#             return len(h[1].data)
#     except Exception as e:
#         print(f"  (could not read {path}: {e}; using {default} to advance RNG)")
#         return default

# # NOTE: make_data (the EVAL/benchmark script) always loads eval_catalog, so the
# # eval replay uses len(eval_catalog). The train replay assumes the training data
# # generator samples PSF positions the same way (uniform over this field); if it
# # uses a different sampler, swap that draw order in here. Either way the *field-
# # uniform* sampling fixes the distribution, so the verdict is robust to RNG detail.
# NCAT_TRAIN = _catlen(TRAIN_CAT)
# NCAT_EVAL  = _catlen(EVAL_CAT)

# def replay_epsf(base_seed, ncat, n, label):
#     e1 = np.full(n, np.nan); e2 = np.full(n, np.nan)
#     for i in range(n):
#         rng = np.random.RandomState(base_seed + i)      # fresh per-object RandomState, exactly as make_data
#         _ = rng.randint(ncat)                            # galaxy index draw (advance state)
#         _ = rng.uniform(low=-SCALE_/2, high=SCALE_/2, size=2)   # dx, dy (advance state)
#         x_im = rng.randint(MARGIN, IMAGE_XSIZE - MARGIN)
#         y_im = rng.randint(MARGIN, IMAGE_YSIZE - MARGIN)
#         try:
#             psf = GP.getPSF(galsim.PositionD(x_im, y_im))
#             img = psf.drawImage(nx=PSF_NPIX_, ny=PSF_NPIX_, scale=SCALE_)
#             sh  = galsim.hsm.FindAdaptiveMom(img).observed_shape
#             e1[i], e2[i] = sh.g1, sh.g2
#         except Exception:
#             pass
#         if (i + 1) % 5000 == 0:
#             print(f"  {label}: {i+1}/{n}")
#     m = np.isfinite(e1) & np.isfinite(e2)
#     print(f"  {label}: {m.sum()}/{n} measured")
#     return e1[m], e2[m]

# print(f"Replaying TRAIN positions (seed {TRAIN_SEED}) ...")
# e1_tr, e2_tr = replay_epsf(TRAIN_SEED, NCAT_TRAIN, N_SAMPLE, 'train')
# print(f"Replaying EVAL positions  (seed {EVAL_SEED}) ...")
# e1_ev, e2_ev = replay_epsf(EVAL_SEED,  NCAT_EVAL,  N_SAMPLE, 'eval')

# # --- stats helpers (reuse §4's if present) ---
# try:
#     _summ
# except NameError:
#     from scipy.stats import skew as _skew
#     def _summ(x, label):
#         x = np.asarray(x, float); x = x[np.isfinite(x)]
#         return dict(label=label, n=x.size, mean=x.mean(), std=x.std(), skew=_skew(x),
#                     lo=np.percentile(x, 0.5), hi=np.percentile(x, 99.5), arr=x)
# from scipy.stats import ks_2samp

# def _verdict(tr, ev, comp):
#     ks = ks_2samp(tr['arr'], ev['arr']); ratio = tr['std'] / ev['std']
#     if ks.pvalue > 1e-3 and 0.95 <= ratio <= 1.0526:
#         v = 'EQUAL  (seed only changes the realization, not the distribution)'
#     elif ratio < 0.95:
#         v = 'train WORSE  (narrower e_PSF coverage than eval)'
#     else:
#         v = 'train BETTER (wider e_PSF coverage than eval)'
#     print(f"[{comp}]  std_tr/std_ev={ratio:.3f}  mean_tr={tr['mean']:+.4f} "
#           f"mean_ev={ev['mean']:+.4f}  KS D={ks.statistic:.3f} p={ks.pvalue:.2e}\n   -> {v}")

# S1t, S1e = _summ(e1_tr, 'e1 train'), _summ(e1_ev, 'e1 eval')
# S2t, S2e = _summ(e2_tr, 'e2 train'), _summ(e2_ev, 'e2 eval')
# print("\n=== Train-vs-eval PSF distribution verdict ===")
# _verdict(S1t, S1e, 'e1_PSF'); _verdict(S2t, S2e, 'e2_PSF')

# # --- validate the replay against the real eval gpsf in the FITS (em5) ---
# try:
#     e1_psf_lk, e2_psf_lk
#     print("\n=== Replay validation: eval-seed HSM replay vs real eval FITS gpsf (em5) ===")
#     for rep, fitcol, nm in [(e1_ev, e1_psf_lk, 'e1'), (e2_ev, e2_psf_lk, 'e2')]:
#         ksv = ks_2samp(rep, np.asarray(fitcol, float))
#         print(f"  {nm}: std_replay={rep.std():.4f} std_fits={np.std(fitcol):.4f} "
#               f"KS p={ksv.pvalue:.2e}  ({'match' if ksv.pvalue>1e-3 else 'differ — check convention/measurement'})")
# except NameError:
#     print("\n(run §3 to enable replay-vs-FITS validation overlay)")

# # --- plots: train vs eval for each component, + per-bin coverage ---
# fig, ax = plt.subplots(2, 2, figsize=(13, 9))
# for j, (tr, ev, nm, col) in enumerate([
#         (e1_tr, e1_ev, r'e_1^{\rm PSF}', COLORS['ngmix'][0]),
#         (e2_tr, e2_ev, r'e_2^{\rm PSF}', COLORS['ngmix'][1])]):
#     rr = (min(tr.min(), ev.min()), max(tr.max(), ev.max())); b = np.linspace(*rr, 60)
#     ax[0,j].hist(tr, bins=b, density=True, histtype='step', lw=2, color=col, label=f'train ({TRAIN_SEED})')
#     ax[0,j].hist(ev, bins=b, density=True, histtype='step', lw=2, ls='--', color=col, label=f'eval ({EVAL_SEED})')
#     if j == 0 and 'e1_psf_lk' in dir():
#         ax[0,j].hist(np.asarray(e1_psf_lk, float), bins=b, density=True, histtype='step',
#                      lw=1.2, color='k', alpha=0.55, label='eval FITS (em5)')
#     if j == 1 and 'e2_psf_lk' in dir():
#         ax[0,j].hist(np.asarray(e2_psf_lk, float), bins=b, density=True, histtype='step',
#                      lw=1.2, color='k', alpha=0.55, label='eval FITS (em5)')
#     ax[0,j].set_title(f'${nm}$ marginals — train vs eval'); ax[0,j].set_xlabel(f'${nm}$')
#     ax[0,j].set_ylabel('density'); ax[0,j].legend()
#     edges = np.linspace(*rr, NBIN + 1); cen = 0.5 * (edges[:-1] + edges[1:])
#     ct, _ = np.histogram(tr, bins=edges); ce, _ = np.histogram(ev, bins=edges)
#     w = (edges[1] - edges[0]) * 0.4
#     ax[1,j].bar(cen - w/2, ct, width=w, color=col, alpha=0.9,  label='train')
#     ax[1,j].bar(cen + w/2, ce, width=w, color=col, alpha=0.45, label='eval')
#     ax[1,j].axhline(MIN_COUNT, color='k', ls='--', lw=1, label=f'MIN_COUNT={MIN_COUNT}')
#     ax[1,j].set_title(f'${nm}$ per-bin counts (NBIN={NBIN})')
#     ax[1,j].set_xlabel(f'${nm}$ bin'); ax[1,j].set_ylabel('objects / bin'); ax[1,j].legend()

# plt.suptitle(f'Train ({TRAIN_SEED}) vs Eval ({EVAL_SEED}) PSF distribution — same PSFEx file',
#              fontsize=15, y=1.01)
# plt.tight_layout()
# plt.savefig(os.path.join(LEAKAGE_DIR, "train_vs_eval_psf_distribution.png"), dpi=150, bbox_inches="tight")
# print(f"\nSaved \u2192 {os.path.join(LEAKAGE_DIR, 'train_vs_eval_psf_distribution.png')}")
# plt.show()
